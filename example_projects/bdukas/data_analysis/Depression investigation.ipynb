# %%
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# I began my analysis of the depression dataset by importing it and running some basic investigations.

# %%
depression_df = pd.read_csv('../data/Raw/with-depression.csv')
depression_df.shape
# Out:
# (6468, 4)

# %%
depression_df.sample()
# Out:
#          Entity Code  Year  \
# 3658  Mauritius  MUS  2008
#
#       Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent) (%)
# 3658                                           3.576573

# %%
depression_df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent) (%)'],
#       dtype='object')

# %% [markdown]
# I renamed a column to make it easier to manipulate.

# %%
depression_df = depression_df.rename(columns={'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent) (%)':'Depression_percent'})

# %% [markdown]
# I continued my basic investigations.

# %%
depression_df.head()
# Out:
#         Entity Code  Year  Depression_percent
# 0  Afghanistan  AFG  1990            4.071831
# 1  Afghanistan  AFG  1991            4.079531
# 2  Afghanistan  AFG  1992            4.088358
# 3  Afghanistan  AFG  1993            4.096190
# 4  Afghanistan  AFG  1994            4.099582

# %%
depression_df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017])

# %%
depression_df['Entity'].nunique()
# Out:
# 231

# %% [markdown]
# I imported my continents dataset.

# %%
continents_df = pd.read_csv('../data/Raw/countries_continents2.csv')

# %% [markdown]
# Then I merged it with the depression dataset. 191 of the 231 entities in the original depression dataset remain in the merged one. However, since this is close to the number of countries in the world, I am satisfied. I care less about the territories listed in the depression dataset.

# %%
merged_df = depression_df.merge(continents_df, left_on='Entity', right_on='Country')
merged_df['Entity'].nunique()
# Out:
# 191

# %%
merged_df['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %% [markdown]
# I then pulled the mean, max, and min values of depression percent by continent.

# %%
merged_df.groupby('Continent')['Depression_percent'].agg(['mean', 'min','max'])
# Out:
#                    mean       min       max
# Continent
# Africa         3.771239  2.885115  5.744704
# Asia           3.376109  2.233269  5.116345
# Europe         3.585069  2.139903  5.512826
# North America  3.130038  2.535758  6.602754
# Oceania        3.321411  2.913340  4.929038
# South America  3.278590  2.194091  4.401565

# %%
import seaborn as sns
import plotly_express as px
import math

# %%
pop_df = pd.read_csv('../data/Cleaned/world_pop_long')
pop_df['Location'].unique()
# Out:
# array(['World', 'More developed regions', 'Less developed regions',
#        'Least developed countries',
#        'Less developed regions, excluding least developed countries',
#        'Less developed regions, excluding China',
#        'Land-locked Developing Countries (LLDC)',
#        'Small Island Developing States (SIDS)', 'High-income countries',
#        'Middle-income countries', 'Upper-middle-income countries',
#        'Lower-middle-income countries', 'Low-income countries',
#        'No income group available', 'Africa', 'Asia', 'Europe',
#        'Latin America and the Caribbean', 'Northern America', 'Oceania',
#        'Sub-Saharan Africa', 'Eastern Africa', 'Burundi', 'Comoros',
#        'Djibouti', 'Eritrea', 'Ethiopia', 'Kenya', 'Madagascar', 'Malawi',
#        'Mauritius', 'Mayotte', 'Mozambique', 'Réunion', 'Rwanda',
#        'Seychelles', 'Somalia', 'South Sudan', 'Uganda', 'Tanzania',
#        'Zambia', 'Zimbabwe', ' Middle Africa', 'Angola', 'Cameroon',
#        'Central African Republic', 'Chad', 'Congo', 'Equatorial Guinea',
#        'Gabon', 'Sao Tome and Principe', 'Southern Africa', 'Botswana',
#        'Swaziland', 'Lesotho', 'Namibia', 'South Africa',
#        'Western Africa', 'Benin', 'Burkina Faso', 'Cape Verde',
#        "Côte d'Ivoire", 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau',
#        'Liberia', 'Mali', 'Mauritania', 'Niger', 'Nigeria',
#        'Saint Helena', 'Senegal', 'Sierra Leone', 'Togo',
#        'Northern Africa and Western Asia', ' Northern Africa', 'Algeria',
#        'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia', 'Western Sahara',
#        'Western Asia', 'Armenia', 'Azerbaijan', 'Bahrain', 'Cyprus',
#        'Georgia', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman',
#        'Qatar', 'Saudi Arabia', 'Palestine', 'Syria', 'Turkey',
#        'United Arab Emirates', 'Yemen', 'Central and Southern Asia',
#        ' Central Asia', 'Kazakhstan', 'Kyrgyzstan', 'Tajikistan',
#        'Turkmenistan', 'Uzbekistan', 'Southern Asia', 'Afghanistan',
#        'Bangladesh', 'Bhutan', 'India', 'Iran', 'Maldives', 'Nepal',
#        'Pakistan', 'Sri Lanka', 'Eastern and South-Eastern Asia',
#        'Eastern Asia', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, Taiwan Province of China',
#        "Dem. People's Republic of Korea", 'Japan', 'Mongolia',
#        'South Korea', 'South-Eastern Asia', 'Brunei', 'Cambodia',
#        'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines',
#        'Singapore', 'Thailand', 'Timor', 'Vietnam', ' Caribbean',
#        'Anguilla', 'Antigua and Barbuda', 'Aruba', 'Bahamas', 'Barbados',
#        'Bonaire, Sint Eustatius and Saba', 'British Virgin Islands',
#        'Cayman Islands', 'Cuba', 'Curaçao', 'Dominica',
#        'Dominican Republic', 'Grenada', 'Guadeloupe', 'Haiti', 'Jamaica',
#        'Martinique', 'Montserrat', 'Puerto Rico', 'Saint Barthélemy',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Martin (French part)', 'Saint Vincent and the Grenadines',
#        'Sint Maarten (Dutch part)', 'Trinidad and Tobago',
#        'Turks and Caicos Islands', 'United States Virgin Islands',
#        'Central America', 'Belize', 'Costa Rica', 'El Salvador',
#        'Guatemala', 'Honduras', 'Mexico', 'Nicaragua', 'Panama',
#        ' South America', 'Argentina', 'Bolivia', 'Brazil', 'Chile',
#        'Colombia', 'Ecuador', 'Falkland Islands (Malvinas)',
#        'French Guiana', 'Guyana', 'Paraguay', 'Peru', 'Suriname',
#        'Uruguay', 'Venezuela', 'Australia/New Zealand', 'Australia',
#        'New Zealand', 'Oceania (excluding Australia and New Zealand)',
#        'Melanesia', 'Fiji', 'New Caledonia', 'Papua New Guinea',
#        'Solomon Islands', 'Vanuatu', ' Micronesia', 'Guam', 'Kiribati',
#        'Marshall Islands', 'Micronesia (country)', 'Nauru',
#        'Northern Mariana Islands', 'Palau', 'Polynesia', 'American Samoa',
#        'Cook Islands', 'French Polynesia', 'Niue', 'Samoa', 'Tokelau',
#        'Tonga', 'Tuvalu', 'Wallis and Futuna Islands',
#        'Europe and Northern America', 'Eastern Europe', 'Belarus',
#        'Bulgaria', 'Czech Republic', 'Hungary', 'Poland', 'Moldova',
#        'Romania', 'Russia', 'Slovakia', 'Ukraine', 'Northern Europe',
#        'ChannelIslands', 'Denmark', 'Estonia', 'Faroe Islands', 'Finland',
#        'Iceland', 'Ireland', 'Isle of Man', 'Latvia', 'Lithuania',
#        'Norway', 'Sweden', 'United Kingdom', 'Southern Europe', 'Albania',
#        'Andorra', 'Bosnia and Herzegovina', 'Croatia', 'Gibraltar',
#        'Greece', 'Holy See', 'Italy', 'Malta', 'Montenegro',
#        'North Macedonia', 'Portugal', 'San Marino', 'Serbia', 'Slovenia',
#        'Spain', 'Western Europe', 'Austria', 'Belgium', 'France',
#        'Germany', 'Liechtenstein', 'Luxembourg', 'Monaco', 'Netherlands',
#        'Switzerland', 'Bermuda', 'Canada', 'Greenland',
#        'Saint Pierre and Miquelon', 'United States'], dtype=object)

# %% [markdown]
# After importing the long population dataset I developed in (data_analysis_Anxiety Investigation), I merged it with my depression dataset.

# %%
dp_df = merged_df.merge(pop_df, left_on=['Year', 'Entity'], right_on=['variable', 'Location'])
dp_df.shape
# Out:
# (5320, 13)

# %% [markdown]
# I successfully merged 189 countries into this new dataset.

# %%
dp_df['Entity'].nunique()
# Out:
# 189

# %% [markdown]
# I then created a new variable that represented each country's actual population, since the original value was by thousand.

# %%
dp_df['Population']=dp_df['value']*1000

# %%
dp_df.head()
# Out:
#         Entity Code  Year  Depression_percent  Unnamed: 0      Country  \
# 0  Afghanistan  AFG  1990            4.071831           0  Afghanistan
# 1  Afghanistan  AFG  1991            4.079531           0  Afghanistan
# 2  Afghanistan  AFG  1992            4.088358           0  Afghanistan
# 3  Afghanistan  AFG  1993            4.096190           0  Afghanistan
# 4  Afghanistan  AFG  1994            4.099582           0  Afghanistan
#
#           Region Continent  code     Location      Average  variable    value  \
# 0  Southern Asia      Asia     4  Afghanistan  24737.62069      1990  12412.0
# 1  Southern Asia      Asia     4  Afghanistan  24737.62069      1991  13299.0
# 2  Southern Asia      Asia     4  Afghanistan  24737.62069      1992  14486.0
# 3  Southern Asia      Asia     4  Afghanistan  24737.62069      1993  15817.0
# 4  Southern Asia      Asia     4  Afghanistan  24737.62069      1994  17076.0
#
#    Population
# 0  12412000.0
# 1  13299000.0
# 2  14486000.0
# 3  15817000.0
# 4  17076000.0

# %% [markdown]
# Next, I created a variable to figure out the number of individuals with depression for each datapoint.

# %%
dp_df['Depression_population']=dp_df['Depression_percent']/100 * dp_df['Population']
dp_df.head()
# Out:
#         Entity Code  Year  Depression_percent  Unnamed: 0      Country  \
# 0  Afghanistan  AFG  1990            4.071831           0  Afghanistan
# 1  Afghanistan  AFG  1991            4.079531           0  Afghanistan
# 2  Afghanistan  AFG  1992            4.088358           0  Afghanistan
# 3  Afghanistan  AFG  1993            4.096190           0  Afghanistan
# 4  Afghanistan  AFG  1994            4.099582           0  Afghanistan
#
#           Region Continent  code     Location      Average  variable    value  \
# 0  Southern Asia      Asia     4  Afghanistan  24737.62069      1990  12412.0
# 1  Southern Asia      Asia     4  Afghanistan  24737.62069      1991  13299.0
# 2  Southern Asia      Asia     4  Afghanistan  24737.62069      1992  14486.0
# 3  Southern Asia      Asia     4  Afghanistan  24737.62069      1993  15817.0
# 4  Southern Asia      Asia     4  Afghanistan  24737.62069      1994  17076.0
#
#    Population  Depression_population
# 0  12412000.0          505395.685697
# 1  13299000.0          542536.819099
# 2  14486000.0          592239.575077
# 3  15817000.0          647894.356027
# 4  17076000.0          700044.550287

# %% [markdown]
# I dropped the replicated variables in the data.

# %%
dp3_df = dp_df.drop(['Country', 'Location','value', 'variable', 'code'], axis=1)

# %% [markdown]
# I renamed the average column to 'Average Pop' to make it more clear that it represented the average population of a country between 1990 and 2017.

# %%
dp3_df.rename(columns={'Average':'Average_pop'})
# Out:
#            Entity Code  Year  Depression_percent  Unnamed: 0           Region  \
# 0     Afghanistan  AFG  1990            4.071831           0    Southern Asia
# 1     Afghanistan  AFG  1991            4.079531           0    Southern Asia
# 2     Afghanistan  AFG  1992            4.088358           0    Southern Asia
# 3     Afghanistan  AFG  1993            4.096190           0    Southern Asia
# 4     Afghanistan  AFG  1994            4.099582           0    Southern Asia
# 5     Afghanistan  AFG  1995            4.104207           0    Southern Asia
# 6     Afghanistan  AFG  1996            4.107500           0    Southern Asia
# 7     Afghanistan  AFG  1997            4.110834           0    Southern Asia
# 8     Afghanistan  AFG  1998            4.114438           0    Southern Asia
# 9     Afghanistan  AFG  1999            4.117633           0    Southern Asia
# 10    Afghanistan  AFG  2000            4.118610           0    Southern Asia
# 11    Afghanistan  AFG  2001            4.121381           0    Southern Asia
# 12    Afghanistan  AFG  2002            4.124928           0    Southern Asia
# 13    Afghanistan  AFG  2003            4.125230           0    Southern Asia
# 14    Afghanistan  AFG  2004            4.126384           0    Southern Asia
# 15    Afghanistan  AFG  2005            4.126908           0    Southern Asia
# 16    Afghanistan  AFG  2006            4.128638           0    Southern Asia
# 17    Afghanistan  AFG  2007            4.129728           0    Southern Asia
# 18    Afghanistan  AFG  2008            4.129656           0    Southern Asia
# 19    Afghanistan  AFG  2009            4.129972           0    Southern Asia
# 20    Afghanistan  AFG  2010            4.130874           0    Southern Asia
# 21    Afghanistan  AFG  2011            4.130862           0    Southern Asia
# 22    Afghanistan  AFG  2012            4.132485           0    Southern Asia
# 23    Afghanistan  AFG  2013            4.134661           0    Southern Asia
# 24    Afghanistan  AFG  2014            4.133526           0    Southern Asia
# 25    Afghanistan  AFG  2015            4.135419           0    Southern Asia
# 26    Afghanistan  AFG  2016            4.135694           0    Southern Asia
# 27    Afghanistan  AFG  2017            4.136347           0    Southern Asia
