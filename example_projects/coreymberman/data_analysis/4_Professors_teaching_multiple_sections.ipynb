# %% [markdown]
# # Data Analysis (part 4)
#
# ## Professors who teach multiple sections of the same course in the same semester
# * This is not so common in Annenberg, but it is common in other departments that are popular in SAS
# * Let's look at Economics professors to prove this point

# %%
# %matplotlib inline

import json
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import numpy as np
import matplotlib.pyplot as plt
import requests
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import plotly_express as px
import math
import plotly

# %% [markdown]
# The first step will be repeating the procedure for loading in and cleaning the data, this time for ECON:

# %%
#repeating procedure for loading and cleaning data

econ_revs1 = requests.get('http://api.penncoursereview.com/v1/depts/econ/reviews/?token=rPY7nzxkE0Dqjzlu9LUDX2mV30W0qo').json()

econ_revs_df = json_normalize(econ_revs1['result']['values'])

### Cleaning the columns for our analysis

econ_revs_df2 = econ_revs_df.drop(columns=['comments','id', 'instructor.id', 'instructor.name','instructor.path','path','section.aliases',
                          'section.id','section.path',])

econ_revs_df2.columns = ['instructor_first', 'instructor_last', 
                         'num_reviewers','num_students', 
                      'AmountLearned',
       'CommAbility', 'CourseQuality', 'Difficulty',
       'InstructorAccess', 'InstructorQuality',
       'ReadingsValue', 'RecommendMajor',
       'RecommendNonMajor', 'StimulateInterest',
       'TAQuality', 'WorkRequired', 'CourseTitle',
       'CourseCode', 'Section', 'Semester']

#converting to numeric so we can work with stats
econ_revs_df2[['CourseQuality', 'InstructorQuality', 'Difficulty',
       'AmountLearned', 'WorkRequired', 'StimulateInterest',
       'InstructorAccess', 'CommAbility', 'ReadingsValue', 'TAQuality',
       'RecommendMajor', 'RecommendNonMajor', 'num_reviewers',
            'num_students']] = econ_revs_df2[['CourseQuality', 'InstructorQuality', 'Difficulty',
       'AmountLearned', 'WorkRequired', 'StimulateInterest',
       'InstructorAccess', 'CommAbility', 'ReadingsValue', 'TAQuality',
       'RecommendMajor', 'RecommendNonMajor', 'num_reviewers', 'num_students']].apply(pd.to_numeric)

#to split a course code to get level
econ_revs_df2['level']= econ_revs_df2['CourseCode'].apply(lambda v: v.split("-")[1])

#reordering the columns
econ_revs_df2 = econ_revs_df2[['CourseCode','level','Section','CourseTitle','Semester','instructor_first',
 'instructor_last','CourseQuality','InstructorQuality','Difficulty','AmountLearned','WorkRequired',
'StimulateInterest','InstructorAccess','CommAbility','ReadingsValue','TAQuality','RecommendMajor',
'RecommendNonMajor','num_reviewers','num_students']]

econ_revs_df2.head(5)
# Out:
#      CourseCode level Section CourseTitle Semester instructor_first  \
# 0  ECON-001-001   001     001     LECTURE    2002A          REBECCA
# 1  ECON-001-002   001     002     LECTURE    2002A          REBECCA
# 2  ECON-002-001   002     001     LECTURE    2002A            WENDY
# 3  ECON-002-002   002     002     LECTURE    2002A            WENDY
# 4  ECON-002-003   002     003     LECTURE    2002A            WENDY
#
#   instructor_last  CourseQuality  InstructorQuality  Difficulty  ...  \
# 0           STEIN           2.52               2.97        2.82  ...
# 1           STEIN           2.48               2.82        2.60  ...
# 2           EUDEY           3.03               3.47        2.59  ...
# 3           EUDEY           3.26               3.61        2.57  ...
# 4           EUDEY           3.08               3.41        2.52  ...
#
#    WorkRequired  StimulateInterest  InstructorAccess  CommAbility  \
# 0          2.22               2.40              3.13         2.88
# 1          2.17               2.26              3.01         2.76
# 2          2.17               3.13              3.38         3.43
# 3          2.18               3.29              3.35         3.58
# 4          2.01               3.10              3.22         3.48
#
#    ReadingsValue  TAQuality  RecommendMajor  RecommendNonMajor  num_reviewers  \
# 0           2.29        NaN            3.57               2.40             98
# 1           2.29        NaN            3.41               2.52            154
# 2           2.25        NaN            3.66               2.95            104
# 3           2.64        NaN            3.68               3.13            117
# 4           2.35        NaN            3.63               2.95            144
#
#    num_students
# 0           195
# 1           195
# 2           156
# 3           162
# 4           160
#
# [5 rows x 21 columns]

# %%
# saving the raw data
econ_revs_df.to_csv('../data/raw_data/econ_revs_df',index=False)

# %%
# saving the cleaned data
econ_revs_df2.to_csv('../data/clean_data/econ_revs_df2',index=False)

# %% [markdown]
# #### We need to identify which professors teach multiple sections in a semester. For each semester, which instructors appear more than once?

# %%
multiple = econ_revs_df2[econ_revs_df2.duplicated(subset=['Semester','instructor_last','level'], keep=False)]
multiple
# Out:
#         CourseCode level Section                      CourseTitle Semester  \
# 0     ECON-001-001   001     001                          LECTURE    2002A
# 1     ECON-001-002   001     002                          LECTURE    2002A
# 2     ECON-002-001   002     001                          LECTURE    2002A
# 3     ECON-002-002   002     002                          LECTURE    2002A
# 4     ECON-002-003   002     003                          LECTURE    2002A
# 5     ECON-002-004   002     004                          LECTURE    2002A
# 6     ECON-002-005   002     005                          LECTURE    2002A
# 8     ECON-003-001   003     001                 MICROECON THEORY    2002A
# 9     ECON-003-002   003     002                 MICROECON THEORY    2002A
# 17    ECON-005-002   005     002                 STAT FOR ECONSTS    2002A
# 18    ECON-005-003   005     003                 STAT FOR ECONSTS    2002A
# 39    ECON-001-001   001     001                          LECTURE    2003A
# 40    ECON-001-002   001     002                          LECTURE    2003A
# 42    ECON-002-001   002     001                          LECTURE    2003A
# 43    ECON-002-002   002     002                          LECTURE    2003A
# 44    ECON-002-003   002     003                          LECTURE    2003A
# 45    ECON-002-004   002     004                          LECTURE    2003A
# 46    ECON-002-005   002     005                          LECTURE    2003A
# 48    ECON-003-001   003     001                 MICROECON THEORY    2003A
# 49    ECON-003-002   003     002                 MICROECON THEORY    2003A
# 64    ECON-050-001   050     001          INTERNATIONAL ECONOMICS    2003A
# 65    ECON-050-002   050     002          INTERNATIONAL ECONOMICS    2003A
# 81    ECON-001-001   001     001                          LECTURE    2002C
# 82    ECON-001-002   001     002                          LECTURE    2002C
# 83    ECON-001-003   001     003                          LECTURE    2002C
# 84    ECON-001-004   001     004                          LECTURE    2002C
# 85    ECON-001-005   001     005                          LECTURE    2002C
# 86    ECON-001-006   001     006                          LECTURE    2002C
# 88    ECON-002-001   002     001                          LECTURE    2002C
# 89    ECON-002-002   002     002                          LECTURE    2002C
# ...            ...   ...     ...                              ...      ...
# 1099  ECON-010-001   010     001            INTRO TO ECON FOR BUS    2016C
# 1100  ECON-010-001   010     001            INTRO TO ECON FOR BUS    2016C
# 1101  ECON-010-002   010     002            INTRO TO ECON FOR BUS    2016C
# 1102  ECON-010-002   010     002            INTRO TO ECON FOR BUS    2016C
# 1124  ECON-001-001   001     001              INTRO TO ECON MICRO    2017C
# 1125  ECON-001-002   001     002              INTRO TO ECON MICRO    2017C
# 1126  ECON-001-003   001     003              INTRO TO ECON MICRO    2017C
# 1128  ECON-002-001   002     001              INTRO TO ECON MACRO    2017C
# 1129  ECON-002-002   002     002              INTRO TO ECON MACRO    2017C
# 1131  ECON-010-001   010     001            INTRO TO ECON FOR BUS    2017C
# 1132  ECON-010-002   010     002            INTRO TO ECON FOR BUS    2017C
# 1158  ECON-001-001   001     001              INTRO TO ECON MICRO    2017A
# 1159  ECON-001-002   001     002              INTRO TO ECON MICRO    2017A
# 1161  ECON-002-001   002     001              INTRO TO ECON MACRO    2017A
# 1162  ECON-002-002   002     002              INTRO TO ECON MACRO    2017A
# 1183  ECON-001-001   001     001  INTRODUCTION TO MICRO ECONOMICS    2018A
# 1184  ECON-001-002   001     002                 INTRO ECON MICRO    2018A
# 1186  ECON-002-001   002     001                 INTRO ECON MACRO    2018A
# 1187  ECON-002-002   002     002                 INTRO ECON MACRO    2018A
# 1222  ECON-001-001   001     001                 INTRO ECON MICRO    2018C
# 1223  ECON-001-002   001     002                 INTRO ECON MICRO    2018C
# 1224  ECON-001-003   001     003                 INTRO ECON MICRO    2018C
# 1226  ECON-002-001   002     001                 INTRO ECON MACRO    2018C
# 1227  ECON-002-002   002     002                 INTRO ECON MACRO    2018C
# 1229  ECON-010-001   010     001            INTRO TO ECON FOR BUS    2018C
# 1230  ECON-010-002   010     002            INTRO TO ECON FOR BUS    2018C
# 1254  ECON-001-001   001     001  INTRODUCTION TO MICRO ECONOMICS    2019A
# 1255  ECON-001-002   001     002                          LECTURE    2019A
# 1257  ECON-002-001   002     001                          LECTURE    2019A
# 1258  ECON-002-002   002     002                          LECTURE    2019A
#
#      instructor_first instructor_last  CourseQuality  InstructorQuality  \
# 0             REBECCA           STEIN           2.52               2.97
# 1             REBECCA           STEIN           2.48               2.82
# 2               WENDY           EUDEY           3.03               3.47
# 3               WENDY           EUDEY           3.26               3.61
# 4               WENDY           EUDEY           3.08               3.41
# 5                JOHN         KNOWLES           2.32               2.27
# 6                JOHN         KNOWLES           2.46               2.40
# 8               JULIO          DAVILA           2.33               2.78
# 9               JULIO          DAVILA           2.64               3.11
# 17          ROBERTO S         MARIANO           1.94               2.18
# 18          ROBERTO S         MARIANO           2.44               3.06
# 39            REBECCA           STEIN           2.64               3.00
# 40            REBECCA           STEIN           2.55               2.98
# 42              WENDY           EUDEY           2.97               3.36
# 43              WENDY           EUDEY           2.96               3.42
# 44              WENDY           EUDEY           3.12               3.39
# 45           YONGSUNG           CHANG           2.47               2.27
# 46           YONGSUNG           CHANG           2.06               1.68
# 48              JULIO          DAVILA           2.23               2.34
# 49              JULIO          DAVILA           2.54               2.73
# 64          STEPHEN R          YEAPLE           3.06               3.39
# 65          STEPHEN R          YEAPLE           2.91               3.30
# 81              URIEL         SPIEGEL           2.51               2.48
# 82            REBECCA           STEIN           2.60               3.10
# 83              URIEL         SPIEGEL           2.43               2.64
# 84            REBECCA           STEIN           2.69               3.08
# 85              URIEL         SPIEGEL           2.41               2.62
# 86            REBECCA           STEIN           2.73               3.30
# 88              WENDY           EUDEY           3.10               3.53
# 89              WENDY           EUDEY           2.76               3.26
# ...               ...             ...            ...                ...
# 1099            GIZEM            SAKA           2.59               2.68
# 1100          ANNE L.         DUCHENE           2.59               3.05
# 1101            GIZEM            SAKA           2.60               2.59
# 1102          ANNE L.         DUCHENE           2.60               3.06
# 1124          ANNE L.         DUCHENE           2.61               2.80
# 1125          ANNE L.         DUCHENE           2.58               2.86
# 1126          ANNE L.         DUCHENE           2.68               2.88
# 1128             LUCA           BOSSI           2.26               2.49
# 1129             LUCA           BOSSI           2.21               2.25
# 1131            GIZEM            SAKA           3.18               3.55
# 1132            GIZEM            SAKA           3.43               3.65
# 1158          REBECCA           STEIN           2.54               2.83
# 1159          REBECCA           STEIN           2.66               2.94
# 1161             LUCA           BOSSI           2.07               2.11
# 1162             LUCA           BOSSI           2.00               1.96
# 1183          ANNE L.         DUCHENE           2.60               2.88
# 1184          ANNE L.         DUCHENE           2.54               2.98
# 1186             LUCA           BOSSI           1.93               1.88
# 1187             LUCA           BOSSI           1.79               1.79
# 1222          ANNE L.         DUCHENE           2.49               2.67
# 1223          ANNE L.         DUCHENE           2.52               2.79
# 1224          ANNE L.         DUCHENE           2.60               2.86
# 1226             LUCA           BOSSI           1.97               1.98
# 1227             LUCA           BOSSI           1.98               2.04
# 1229            GIZEM            SAKA           3.12               3.32
# 1230            GIZEM            SAKA           3.08               3.38
# 1254          ANNE L.         DUCHENE           2.74               3.20
# 1255          ANNE L.         DUCHENE           2.81               3.10
# 1257             LUCA           BOSSI           1.70               1.63
# 1258             LUCA           BOSSI           1.51               1.48
#
#       Difficulty  ...  WorkRequired  StimulateInterest  InstructorAccess  \
# 0           2.82  ...          2.22               2.40              3.13
# 1           2.60  ...          2.17               2.26              3.01
# 2           2.59  ...          2.17               3.13              3.38
# 3           2.57  ...          2.18               3.29              3.35
# 4           2.52  ...          2.01               3.10              3.22
# 5           2.79  ...          2.33               2.14              2.34
# 6           2.75  ...          2.42               2.22              2.30
# 8           2.85  ...          2.07               2.07              3.08
# 9           2.64  ...          2.17               2.14              2.85
# 17          3.00  ...          2.53               1.94              2.53
# 18          3.11  ...          2.72               2.44              3.17
# 39          2.59  ...          2.13               2.28              3.18
# 40          2.68  ...          2.19               2.37              3.09
# 42          2.36  ...          2.17               2.79              3.26
# 43          2.46  ...          2.09               2.94              3.21
# 44          2.53  ...          2.08               2.97              3.27
# 45          2.63  ...          2.27               1.80              2.66
# 46          2.38  ...          1.98               1.10              2.09
# 48          2.63  ...          2.20               1.66              2.24
# 49          2.46  ...          2.12               1.73              2.59
# 64          2.72  ...          2.26               2.91              3.29
# 65          2.63  ...          2.25               2.58              3.26
# 81          2.77  ...          2.20               2.21              2.96
# 82          2.77  ...          2.44               2.58              3.01
# 83          2.77  ...          2.41               2.40              2.98
# 84          2.68  ...          2.21               2.63              2.99
# 85          2.69  ...          2.31               2.55              2.70
# 86          2.71  ...          2.35               2.82              3.17
# 88          2.45  ...          2.10               3.07              3.54
# 89          2.45  ...          2.09               2.59              3.43
# ...          ...  ...           ...                ...               ...
# 1099        2.38  ...          1.99               2.78              2.49
# 1100        2.38  ...          1.99               3.05              2.69
# 1101        2.44  ...          2.01               2.75              2.49
# 1102        2.44  ...          2.01               3.05              2.82
# 1124        2.84  ...          2.49               2.90              2.87
# 1125        2.69  ...          2.31               2.83              2.85
# 1126        2.59  ...          2.20               2.89              2.88
# 1128        2.94  ...          2.62               2.85              3.05
# 1129        2.87  ...          2.32               2.32              2.84
# 1131        2.35  ...          2.09               3.42              2.39
# 1132        2.40  ...          2.13               3.51              2.41
# 1158        2.78  ...          2.91               2.81              3.06
# 1159        2.70  ...          2.82               2.92              3.07
# 1161        2.95  ...          2.59               2.31              2.81
# 1162        2.82  ...          2.50               2.18              2.71
# 1183        2.59  ...          2.30               2.86              2.91
# 1184        2.65  ...          2.47               2.87              3.11
# 1186        2.84  ...          2.49               2.32              2.62
# 1187        3.05  ...          2.52               2.02              2.69
# 1222        2.73  ...          2.53               2.79              2.85
# 1223        2.76  ...          2.64               2.79              2.92
# 1224        2.68  ...          2.61               2.93              3.03
# 1226        2.78  ...          2.43               2.37              2.70
# 1227        2.92  ...          2.41               2.36              2.70
# 1229        2.33  ...          1.86               3.21              2.46
# 1230        2.46  ...          1.99               3.07              2.27
# 1254        2.31  ...          2.32               3.00              3.22
# 1255        2.83  ...          2.53               3.01              3.00
# 1257        3.04  ...          2.58               2.05              2.53
# 1258        3.16  ...          2.61               1.81              2.53
#
#       CommAbility  ReadingsValue  TAQuality  RecommendMajor  \
# 0            2.88           2.29        NaN            3.57
# 1            2.76           2.29        NaN            3.41
# 2            3.43           2.25        NaN            3.66
# 3            3.58           2.64        NaN            3.68
# 4            3.48           2.35        NaN            3.63
# 5            2.25           2.49        NaN            3.32
# 6            2.31           2.44        NaN            3.39
# 8            2.70           2.44        NaN            3.30
# 9            3.06           2.09        NaN            3.69
# 17           2.00           2.12        NaN            3.06
# 18           2.56           2.44        NaN            3.50
# 39           2.98           2.38        NaN            3.55
# 40           2.98           2.19        NaN            3.53
# 42           3.35           1.91        NaN            3.54
# 43           3.39           1.81        NaN            3.60
# 44           3.41           1.98        NaN            3.56
# 45           2.03           2.57        NaN            3.27
# 46           1.36           2.28        NaN            3.04
# 48           2.09           2.36        NaN            3.25
# 49           2.44           2.50        NaN            3.26
# 64           3.50           2.33        NaN            3.57
# 65           3.32           2.32        NaN            3.39
# 81           2.23           2.52        NaN            3.31
# 82           3.11           2.45        NaN            3.38
# 83           2.24           2.47        NaN            3.40
# 84           3.07           2.21        NaN            3.31
# 85           2.10           2.45        NaN            3.05
# 86           3.24           2.24        NaN            3.44
# 88           3.64           2.13        NaN            3.74
# 89           3.22           1.73        NaN            3.59
# ...           ...            ...        ...             ...
# 1099         2.96            NaN       2.07             NaN
# 1100         3.26            NaN       2.07             NaN
# 1101         2.88            NaN       2.04             NaN
# 1102         3.30            NaN       2.04             NaN
# 1124         3.08            NaN       2.45             NaN
# 1125         3.12            NaN       2.56             NaN
# 1126         3.15            NaN       2.56             NaN
# 1128         2.83            NaN       2.40             NaN
# 1129         2.55            NaN       2.08             NaN
# 1131         3.54            NaN       2.09             NaN
# 1132         3.72            NaN       2.29             NaN
# 1158         3.08            NaN       2.62             NaN
# 1159         2.97            NaN       2.81             NaN
# 1161         2.52            NaN       2.62             NaN
# 1162         2.37            NaN       2.54             NaN
# 1183         3.14            NaN       2.62             NaN
# 1184         3.17            NaN       2.68             NaN
# 1186         2.44            NaN       2.56             NaN
# 1187         2.17            NaN       2.23             NaN
# 1222         3.00            NaN       2.40             NaN
# 1223         3.07            NaN       2.31             NaN
# 1224         3.06            NaN       2.30             NaN
# 1226         2.63            NaN       2.25             NaN
# 1227         2.55            NaN       2.35             NaN
# 1229         3.43            NaN       2.29             NaN
# 1230         3.52            NaN       2.38             NaN
# 1254         3.27            NaN       2.62             NaN
# 1255         3.30            NaN       2.84             NaN
# 1257         2.13            NaN       1.74             NaN
# 1258         1.90            NaN       1.95             NaN
#
#       RecommendNonMajor  num_reviewers  num_students
# 0                  2.40             98           195
# 1                  2.52            154           195
# 2                  2.95            104           156
# 3                  3.13            117           162
# 4                  2.95            144           160
# 5                  2.39             72            97
# 6                  2.34             79           125
# 8                  1.41             27            51
# 9                  1.50             36            43
# 17                 0.65             17            29
# 18                 1.06             18            25
# 39                 2.41            140           213
# 40                 2.45            174           208
# 42                 2.88             78           155
# 43                 2.85            125           166
# 44                 2.79            129           171
# 45                 2.60             31            87
# 46                 2.18             54           122
# 48                 1.63             35            43
# 49                 1.39             42            57
# 64                 2.67             38            79
# 65                 2.02             62            87
# 81                 2.58             84           148
# 82                 2.37            134           159
# 83                 2.45            120           147
# 84                 2.61            105           149
# 85                 2.34            139           140
# 86                 2.52            131           157
# 88                 2.87            100           143
# 89                 2.51            110           147
# ...                 ...            ...           ...
# 1099                NaN            210           214
# 1100                NaN            210           214
# 1101                NaN            177           185
# 1102                NaN            177           185
# 1124                NaN            220           228
# 1125                NaN            217           226
# 1126                NaN            197           203
# 1128                NaN             76            82
# 1129                NaN             55            57
# 1131                NaN            191           195
# 1132                NaN            222           228
# 1158                NaN             74            83
# 1159                NaN            110           120
# 1161                NaN            174           202
# 1162                NaN            205           233
# 1183                NaN             80            85
# 1184                NaN            129           139
# 1186                NaN            169           193
# 1187                NaN            225           259
# 1222                NaN            220           228
# 1223                NaN            216           229
# 1224                NaN            206           224
# 1226                NaN             68            70
# 1227                NaN             83            86
# 1229                NaN            160           175
# 1230                NaN            222           233
# 1254                NaN             78            86
# 1255                NaN            106           118
# 1257                NaN            183           201
# 1258                NaN            211           231
#
# [303 rows x 21 columns]

# %% [markdown]
# #### Now, which courses have been taught multiple sections in a given term?

# %%
# which courses are offered 
multiple['level'].unique()
# Out:
# array(['001', '002', '003', '005', '050', '006', '220', '101', '102',
#        '103', '010', '104', '302'], dtype=object)

# %%
# how many sections are typically offered?
multiple_sections = multiple['Section'].unique()
multiple_sections
# Out:
# array(['001', '002', '003', '004', '005', '006', '401', '402'],
#       dtype=object)

# %%
# who are the professors teaching multiple?
multiple_profs = multiple['instructor_last'].unique()
multiple_profs
# Out:
# array(['STEIN', 'EUDEY', 'KNOWLES', 'DAVILA', 'MARIANO', 'CHANG',
#        'YEAPLE', 'SPIEGEL', 'BRUNETTI', 'DIEBOLD', 'SCHORFHEIDE',
#        'MANOVSKII', 'NOCKE', 'MENZIO', 'DE PAULA', 'KRASNOKUTSKAYA',
#        'GOLAN', 'OZMUCUR', 'LI', 'SONG', 'KIRCHER', 'TANG', 'JAO',
#        'FIELER', 'OKADA', 'CHENG', 'BOSSI', 'BACHMANN', 'SAKA', 'DAVID',
#        'DUCHENE'], dtype=object)

# %%
#let's do one analysis to see how it will work, 
#then iterate over our list of multiple_profs
multiple[multiple['instructor_last']=='STEIN'].groupby('Section').mean()
# Out:
#          CourseQuality  InstructorQuality  Difficulty  AmountLearned  \
# Section
# 001           2.766071           3.184286    2.750714       2.927895
# 002           2.791379           3.202759    2.711724       2.926000
# 003           3.014545           3.379091    2.693636       3.080000
# 004           3.022000           3.426000    2.716000       3.066000
# 006           2.730000           3.300000    2.710000       2.860000
#
#          WorkRequired  StimulateInterest  InstructorAccess  CommAbility  \
# Section
# 001          2.373214           2.919643          3.137857     3.193929
# 002          2.355172           2.952759          3.112414     3.197586
# 003          2.231818           3.138182          3.186364     3.350909
# 004          2.270000           3.142000          3.264000     3.384000
# 006          2.350000           2.820000          3.170000     3.240000
#
#          ReadingsValue  TAQuality  RecommendMajor  RecommendNonMajor  \
# Section
# 001           2.389474   2.828889        3.466316           2.615789
# 002           2.359500   2.882222        3.495500           2.644500
# 003           2.388750   2.780000        3.676250           2.877500
# 004           2.432000        NaN        3.670000           2.904000
# 006           2.240000        NaN        3.440000           2.520000
#
#          num_reviewers  num_students
# Section
# 001         133.785714    178.321429
# 002         160.827586    185.068966
# 003         163.000000    191.272727
# 004         156.600000    185.000000
# 006         131.000000    157.000000

# %% [markdown]
# So Rebecca Stein has taught sections 001 through 006, and her means along various variables do have a somewhat wide range.

# %% [markdown]
# #### We will need to use a for loop to iterate over our list of sections AND our list of professors who teach multiple sections.
# * We will need a new dataframe to store the results
# * We will need an empty array to store the means for each section
# * We need to find where a given professor is teaching the same section more than once
# * This is going to have to include a loop within a loop

# %%
mult_profs_revs = pd.DataFrame()
mult_profs_revs['instructor'] = multiple_profs

#for loop:

for sect in multiple_sections:
    means = []
    for prof in multiple_profs:
        p = multiple[(multiple['instructor_last'] == prof) & 
                     (multiple['Section'] == sect)]['InstructorQuality'].mean()
        means.append(p)
    mult_profs_revs[sect] = means

# %%
mult_profs_revs
# Out:
#         instructor       001       002       003       004     005       006  \
# 0            STEIN  3.184286  3.202759  3.379091  3.426000     NaN  3.300000
# 1            EUDEY  3.073125  3.031250  3.194000       NaN     NaN       NaN
# 2          KNOWLES  2.380000  2.750000       NaN  2.270000  2.4000       NaN
# 3           DAVILA  2.560000  2.920000       NaN       NaN     NaN       NaN
# 4          MARIANO       NaN  2.180000  3.060000       NaN     NaN       NaN
# 5            CHANG       NaN       NaN       NaN  2.270000  1.6800       NaN
# 6           YEAPLE  3.353333  3.313333       NaN       NaN     NaN       NaN
# 7          SPIEGEL  2.195556  2.157500  2.640000  2.606667  2.5125  2.596667
# 8         BRUNETTI  3.320000  3.220000       NaN       NaN     NaN       NaN
# 9          DIEBOLD  3.227500  3.200000       NaN       NaN     NaN       NaN
# 10     SCHORFHEIDE  3.000000  3.000000       NaN       NaN     NaN       NaN
# 11       MANOVSKII  2.372857  2.327143       NaN       NaN     NaN       NaN
# 12           NOCKE  3.170000  3.220000       NaN       NaN     NaN       NaN
# 13          MENZIO  2.790000  2.935000       NaN       NaN     NaN       NaN
# 14        DE PAULA  2.940000  2.860000  2.550000       NaN     NaN       NaN
# 15  KRASNOKUTSKAYA  2.220000  2.350000       NaN       NaN     NaN       NaN
# 16           GOLAN  2.100000       NaN  1.280000       NaN     NaN       NaN
# 17         OZMUCUR  2.506667  2.706667       NaN       NaN     NaN       NaN
# 18              LI  1.515000  2.020000       NaN       NaN     NaN       NaN
# 19            SONG  2.230000  2.060000       NaN       NaN     NaN       NaN
# 20         KIRCHER  3.055000  2.930000       NaN       NaN     NaN       NaN
# 21            TANG       NaN  1.910000  2.165000       NaN     NaN       NaN
# 22             JAO  1.036667  1.346667       NaN       NaN     NaN       NaN
# 23          FIELER  2.020000  2.000000       NaN       NaN     NaN       NaN
# 24           OKADA       NaN  2.290000  2.520000       NaN     NaN       NaN
# 25           CHENG  3.070000  2.410000       NaN       NaN     NaN       NaN
# 26           BOSSI  2.348889  2.263333       NaN       NaN     NaN       NaN
# 27        BACHMANN  1.220000  1.380000       NaN       NaN     NaN       NaN
# 28            SAKA  3.354286  3.318571       NaN       NaN     NaN       NaN
# 29           DAVID       NaN       NaN       NaN       NaN     NaN       NaN
# 30         DUCHENE  2.890000  2.920000  2.745000  2.735000     NaN       NaN
#
#      401   402
# 0    NaN   NaN
# 1    NaN   NaN
# 2    NaN   NaN
# 3    NaN   NaN
# 4    NaN   NaN
# 5    NaN   NaN
# 6    NaN   NaN
# 7    NaN   NaN
# 8    NaN   NaN
# 9    NaN   NaN
# 10   NaN   NaN
# 11   NaN   NaN
# 12   NaN   NaN
# 13   NaN   NaN
# 14   NaN   NaN
# 15   NaN   NaN
# 16   NaN   NaN
# 17   NaN   NaN
# 18   NaN   NaN
# 19   NaN   NaN
# 20   NaN   NaN
# 21   NaN   NaN
# 22   NaN   NaN
# 23   NaN   NaN
# 24   NaN   NaN
# 25   NaN   NaN
# 26   NaN   NaN
# 27   NaN   NaN
# 28   NaN   NaN
# 29  3.24  3.35
# 30   NaN   NaN

# %% [markdown]
# #### Insights from above:
# * NaN values are where a professor has not taught that section number
# * But each professor in the dataframe has taught more than one
# * Typically (cross checked with course rosters historically) the higher numbers are taught later in the day and lower numbers taught first
# * There are differences detectable between a professor's multiple sections taught of a given course within a semester
# * Some professors improve as the day goes on, some not - case-by-case basis but still important for students to check it out
# * It did not make sense to take the means down the columns of the above because a professor-by-professor breakdown is a more fair way to see how things change across sections taught, whereas 001 appears way more often than 006, etc.

# %%
# this very rarely happens in COMM so it is not something that COMM majors must worry about
#does it ever happen in COMM?
comm_revs_df2 = pd.read_csv('../data/clean_data/comm_revs_df2')
comm_revs_df2[comm_revs_df2.duplicated(subset=['Semester','instructor_last','level'], keep=False)]
# Out:
#        CourseCode  level  Section  \
# 278  COMM-281-301    281      301
# 295  ENGL-281-401    281      401
# 452  COMM-399-001    399        1
# 453  COMM-399-002    399        2
# 454  COMM-399-003    399        3
# 455  COMM-399-004    399        4
# 482  ASAM-201-401    201      401
# 483  ASAM-201-601    201      601
#
#                                            CourseTitle Semester  \
# 278                              RACE FILMS: SPIKE LEE    2008C
# 295       Race Films:  Spike Lee and his Interlocutors    2008C
# 452  INDEPENDENT STUDY: Teenagers, Media, and Self-...    2012C
# 453                                  INDEPENDENT STUDY    2012C
# 454  INDEPENDENT STUDY: Safe Sex Messages in Televi...    2012C
# 455  INDEPENDENT STUDY: Non-Profit Partnerships: Sc...    2012C
# 482                  IMMIGRANT URBAN LABOR IN THE U.S.    2013A
# 483                Asian Americans and Popular Culture    2013A
#
#     instructor_first instructor_last  CourseQuality  InstructorQuality  \
# 278          JOHN L.         JACKSON           2.88               3.50
# 295          JOHN L.         JACKSON           3.00               3.42
# 452           AMY B.          JORDAN           4.00               4.00
# 453           AMY B.          JORDAN           3.00               4.00
# 454           AMY B.          JORDAN           4.00               4.00
# 455           AMY B.          JORDAN           4.00               4.00
# 482        TAMARA K.          NOPPER           2.76               3.14
# 483        TAMARA K.          NOPPER           3.34               3.45
#
#      Difficulty  ...  StimulateInterest  InstructorAccess  CommAbility  \
# 278        2.19  ...               3.31              3.38         3.31
# 295        2.25  ...               3.22              3.24         3.31
# 452        2.00  ...               4.00              4.00         4.00
# 453         NaN  ...                NaN               NaN          NaN
# 454         NaN  ...                NaN               NaN          NaN
# 455        3.00  ...               4.00              4.00         4.00
# 482        2.00  ...               3.07              2.87         3.53
# 483        2.16  ...               3.44              2.74         3.60
#
#      ReadingsValue  TAQuality  RecommendMajor  RecommendNonMajor  \
# 278           2.88        NaN            3.13               2.81
# 295           2.75        NaN            3.25               2.75
# 452           4.00        NaN            4.00               4.00
# 453            NaN        NaN             NaN                NaN
# 454            NaN        NaN             NaN                NaN
# 455           4.00        NaN            4.00               3.00
# 482            NaN        NaN             NaN                NaN
# 483            NaN        3.5             NaN                NaN
#
#      num_reviewers  num_students  hundred
# 278             17            18        2
# 295             65            72        2
# 452              1             1        3
# 453              1             1        3
# 454              1             1        3
# 455              1             1        3
# 482             22            24        2
# 483             30            32        2
#
# [8 rows x 22 columns]

# %% [markdown]
# Confirmed: this is not something COMM majors need be concerned with.
