# %% [markdown]
# # Notebook 5
# ## This notebook geocodes the addresses for buildings
#
# * For each year datasheet look for buildings that haven't yet got a geocode run on then and use the lookup on the address.
#
# * Building ID should be either:
#     * `philadelphia_building_id` - 2013, 2014
#
#   or
#
#     * `opa_account_num` - 2015, 2016, 2017

# %%
import pandas as pd
import os
import re

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# * get a list of csv files in the `data` folder
#     * only want CSV files from the data folder that end in _201*.csv, e.g.
#       ```
#         energy_usage_large_commercial_buildings_reported_2013.csv
#         properties_reported_2015.csv
#         ..etc..
#       ```

# %%
data_files = [f for f in os.listdir('../data') if re.search('_201[3-7].csv',f)]
data_files
# Out:
# ['energy_usage_large_commercial_buildings_reported_2014.csv',
#  'energy_usage_large_commercial_buildings_reported_2013.csv',
#  'properties_reported_2015.csv',
#  'properties_reported_2017.csv',
#  'properties_reported_2016.csv']

# %% [markdown]
# * check the data sheets to see which building id column is used

# %%
for dfile in data_files:
    df = pd.read_csv('../data/{}'.format(dfile))
    id_col = 'opa_account_num' if 'opa_account_num' in df.columns else 'philadelphia_building_id'
    print(dfile)
    print('\tBuilding ID is', id_col)
    print('\t', df.columns.sort_values())
    print()
# Out:
# energy_usage_large_commercial_buildings_reported_2014.csv
# 	Building ID is philadelphia_building_id
# 	 Index(['district_steam_use_kbtu', 'electricity_use_kbtu', 'energy_star_score',
#        'fuel_oil_2_use_kbtu', 'location_1_address', 'natural_gas_use_kbtu',
#        'notes', 'number_of_buildings', 'philadelphia_building_id',
#        'portfolio_manager_id', 'postal_code',
#        'primary_property_type_epa_calculated',
#        'property_floor_area_buildings_and_parking_ft', 'property_name',
#        'site_eui_kbtu_ft', 'source_eui_kbtu_ft', 'total_ghg_emissions_mtco2e',
#        'water_use_all_water_sources_kgal', 'year_built'],
#       dtype='object')
#
# energy_usage_large_commercial_buildings_reported_2013.csv
# 	Building ID is philadelphia_building_id
# 	 Index(['district_steam_use_kbtu',
#        'electricity_use_grid_purchase_and_generated_from_onsite_renewab',
#        'energy_star_score', 'fuel_oil_2_use_kbtu', 'geom_address', 'lat',
#        'lng', 'natural_gas_use_kbtu', 'notes', 'number_of_buildings',
#        'philadelphia_building_id', 'portfolio_manager_id', 'postal_code',
#        'primary_property_type_epa_calculated',
#        'property_floor_area_buildings_and_parking_ft', 'property_name',
#        'site_eui_kbtu_ft2', 'source_eui_kbtu_ft2', 'the_geom',
#        'the_geom_webmercator', 'total_ghg_emissions_mtco2e',
#        'water_use_all_water_sources_kgal', 'year_built'],
#       dtype='object')
#
# properties_reported_2015.csv
# 	Building ID is opa_account_num
# 	 Index(['electricity_use_kbtu', 'energy_star_score', 'fuel_oil_o2_use_kbtu',
#        'natural_gas_use_kbtu', 'notes', 'num_of_buildings', 'objectid',
#        'opa_account_num', 'portfolio_manager_id', 'postal_code',
#        'primary_prop_type_epa_calc', 'property_name', 'site_eui_kbtuft2',
#        'source_eui_kbtuft2', 'steam_use_kbtu', 'street_address',
#        'total_floor_area_bld_pk_ft2', 'total_ghg_emissions_mtco2e',
#        'water_use_all_kgal', 'year_built'],
#       dtype='object')
#
# properties_reported_2017.csv
# 	Building ID is opa_account_num
# 	 Index(['electricity_use_kbtu', 'energy_star_score', 'fuel_oil_o2_use_kbtu',
#        'natural_gas_use_kbtu', 'notes', 'num_of_buildings', 'objectid',
#        'opa_account_num', 'portfolio_manager_id', 'postal_code',
#        'primary_prop_type_epa_calc', 'property_name', 'site_eui_kbtuft2',
#        'source_eui_kbtuft2', 'steam_use_kbtu', 'street_address',
#        'total_floor_area_bld_pk_ft2', 'total_ghg_emissions_mtco2e',
#        'water_use_all_kgal', 'year_built'],
#       dtype='object')
#
# properties_reported_2016.csv
# 	Building ID is opa_account_num
# 	 Index(['electricity_use_kbtu', 'energy_star_score', 'fuel_oil_o2_use_kbtu',
#        'natural_gas_use_kbtu', 'notes', 'num_of_buildings', 'objectid',
#        'opa_account_num', 'portfolio_manager_id', 'postal_code',
#        'primary_prop_type_epa_calc', 'property_name', 'site_eui_kbtuft2',
#        'source_eui_kbtuft2', 'steam_use_kbtu', 'street_address',
#        'total_floor_area_bld_pk_ft2', 'total_ghg_emissions_mtco2e',
#        'water_use_all_kgal', 'year_built'],
#       dtype='object')

# %% [markdown]
# ### Mapping between column names
#
# * The 2013 and 2014 data has different column names - need to rename those columns which are matches to the 2015-2017 data frame
#
#
# * Unique to 2013:
#  ```
#  'electricity_use_grid_purchase_and_generated_from_onsite_renewab',
#  'geom_address',
#  'lat',
#  'lng',
#  'site_eui_kbtu_ft2',
#  'source_eui_kbtu_ft2',
#  'the_geom',
#  'the_geom_webmercator'
#  ```
#
#
# * Unique to 2014:
#   ```
#   'location_1_address',
#   'site_eui_kbtu_ft',
#   'source_eui_kbtu_ft'
#   ```
#
# * Unique to 2013-2014:
#   ```
#  'district_steam_use_kbtu',
#  'fuel_oil_2_use_kbtu',
#  'location_1_address',
#  'number_of_buildings',
#  'philadelphia_building_id',
#  'primary_property_type_epa_calculated',
#  'property_floor_area_buildings_and_parking_ft',
#  'site_eui_kbtu_ft',
#  'source_eui_kbtu_ft',
#  'water_use_all_water_sources_kgal'
#  ```
#
#
# * Unique to 2015-2017:
#   ```
#  'fuel_oil_o2_use_kbtu',
#  'num_of_buildings',
#  'objectid',
#  'opa_account_num',
#  'primary_prop_type_epa_calc',
#  'site_eui_kbtuft2',
#  'source_eui_kbtuft2',
#  'steam_use_kbtu',
#  'street_address',
#  'total_floor_area_bld_pk_ft2',
#  'water_use_all_kgal'
#  ```

# %%
c2013 = ['district_steam_use_kbtu',
       'electricity_use_grid_purchase_and_generated_from_onsite_renewab',
       'energy_star_score', 'fuel_oil_2_use_kbtu', 'geom_address', 'lat',
       'lng', 'natural_gas_use_kbtu', 'notes', 'number_of_buildings',
       'philadelphia_building_id', 'portfolio_manager_id', 'postal_code',
       'primary_property_type_epa_calculated',
       'property_floor_area_buildings_and_parking_ft', 'property_name',
       'site_eui_kbtu_ft2', 'source_eui_kbtu_ft2', 'the_geom',
       'the_geom_webmercator', 'total_ghg_emissions_mtco2e',
       'water_use_all_water_sources_kgal', 'year_built']


c2014 = ['district_steam_use_kbtu', 'electricity_use_kbtu', 'energy_star_score',
       'fuel_oil_2_use_kbtu', 'location_1_address', 'natural_gas_use_kbtu',
       'notes', 'number_of_buildings', 'philadelphia_building_id',
       'portfolio_manager_id', 'postal_code',
       'primary_property_type_epa_calculated',
       'property_floor_area_buildings_and_parking_ft', 'property_name',
       'site_eui_kbtu_ft', 'source_eui_kbtu_ft', 'total_ghg_emissions_mtco2e',
       'water_use_all_water_sources_kgal', 'year_built']

c2015_2017 = ['electricity_use_kbtu', 'energy_star_score', 'fuel_oil_o2_use_kbtu',
       'natural_gas_use_kbtu', 'notes', 'num_of_buildings', 'objectid',
       'opa_account_num', 'portfolio_manager_id', 'postal_code',
       'primary_prop_type_epa_calc', 'property_name', 'site_eui_kbtuft2',
       'source_eui_kbtuft2', 'steam_use_kbtu', 'street_address',
       'total_floor_area_bld_pk_ft2', 'total_ghg_emissions_mtco2e',
       'water_use_all_kgal', 'year_built']



set(c2015_2017).difference(set(c2013).union(set(c2014)))

set(c2014).difference(set(c2013).union(set(c2015_2017)))

set(c2013).difference(set(c2014).union(set(c2015_2017)))

set(c2014).union(set(c2015_2017)).difference(set(c2015_2017))
# Out:
# {'district_steam_use_kbtu',
#  'fuel_oil_2_use_kbtu',
#  'location_1_address',
#  'number_of_buildings',
#  'philadelphia_building_id',
#  'primary_property_type_epa_calculated',
#  'property_floor_area_buildings_and_parking_ft',
#  'site_eui_kbtu_ft',
#  'source_eui_kbtu_ft',
#  'water_use_all_water_sources_kgal'}

# %% [markdown]
# ### Find unique building ids and drop all other rows
#
# * There seems to be some duplication in the building ids when a group of buildings, i.e. campus buildings, are considered a unit. The easiest approach is just to drop these rows from the data frame so that the building id is really unique.
#
#
# * Also some rows have missing building ids or have non numeric values in them, `Many` or `Multiple`. These rows should also be dropped from the data frame

# %%
def clean_up_dataframe(df):

    building_id_col = 'opa_account_num' if 'opa_account_num' in df.columns else 'philadelphia_building_id'
    df.rename(columns={building_id_col: 'building_id'}, inplace=True)
    
    building_ids = df['building_id'].value_counts().reset_index()
    keep_ids = building_ids[building_ids['building_id']==1]['index']
    
    missing_filter = -df['building_id'].isnull()
    keep_filter = df['building_id'].isin(keep_ids)
    multiple_filter = -df['building_id'].isin(['Many','Multiple'])

    df=df[missing_filter & keep_filter & multiple_filter]
    
    try:
        semicolon_filter = (df['building_id'].str.contains(';')) | (df['building_id'].str.contains(','))
        df=df[-semicolon_filter]
    except:
        pass
    
    df['building_id']=df['building_id'].astype(int)
    return df

# %% [markdown]
# <div class="alert alert-info">
#     <li>the list of csv files included things like `means.csv` that aren't the actual datasheets so needed to adjust so it is just the 2013-2017 datasheets</li>
# </div>

# %%
dframes=[]
for dfile in data_files:
    year = dfile.split('_')[-1][:-4]
    print(year, dfile)
    df = pd.read_csv('../data/{}'.format(dfile))
    df_clean = clean_up_dataframe(df)
    df_clean['year']=year
    dframes.append(df_clean)
# Out:
# 2014 energy_usage_large_commercial_buildings_reported_2014.csv
# 2013 energy_usage_large_commercial_buildings_reported_2013.csv
# 2015 properties_reported_2015.csv
# 2017 properties_reported_2017.csv
# 2016 properties_reported_2016.csv
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
full_df=pd.concat(dframes)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
full_df.sample(30)
# Out:
#       building_id district_steam_use_kbtu  \
# 908     777630000           Not Available
# 687     771634900                     NaN
# 1291    884209570                     NaN
# 103     882506315              16933926.5
# 1417    881091000                     NaN
# 675     884220900                     NaN
# 722     881021500                     NaN
# 1265    884123105                     NaN
# 746     784093000           Not Available
# 214     784484000                     NaN
# 896     782003200                     NaN
# 738     777570600           22,998,105.30
# 808     888113214                     NaN
# 643     774518010              23336646.7
# 79      883059004                     NaN
# 399     884114510           Not Available
# 632     881156500                     NaN
# 668     883054361           Not Available
# 871     778031022           Not Available
# 506     881421350           Not Available
# 217     786182000                     NaN
# 542     888037050                     NaN
# 500     884019026                     NaN
# 669     882050755                     NaN
# 1171    775501010                     NaN
# 1491    772534600                     NaN
# 119     884091000           Not Available
# 933     882938075           Not Available
# 595     884232400           Not Available
# 456     883041500            7,217,456.40
#
#       electricity_use_grid_purchase_and_generated_from_onsite_renewab  \
# 908                                              6276.7
# 687                                                 NaN
# 1291                                                NaN
# 103                                          22021754.3
# 1417                                                NaN
# 675                                                 NaN
# 722                                                 NaN
# 1265                                                NaN
# 746                                           2548471.6
# 214                                                 NaN
# 896                                                 NaN
# 738                                                 NaN
# 808                                                 NaN
# 643                                          34865658.5
# 79                                                  NaN
# 399                                           1417818.0
# 632                                                 NaN
# 668                                          70293751.0
# 871                                          25463691.2
# 506                                                 NaN
# 217                                                 NaN
# 542                                                 NaN
# 500                                                 NaN
# 669                                                 NaN
# 1171                                                NaN
# 1491                                                NaN
# 119                                                 NaN
# 933                                           1894374.8
# 595                                                 NaN
# 456                                                 NaN
#
#       electricity_use_kbtu energy_star_score fuel_oil_2_use_kbtu  \
# 908                    NaN     Not Available       Not Available
# 687             33324905.1                94                 NaN
# 1291             3120521.0               NaN                 NaN
# 103                    NaN                95       Not Available
# 1417               49460.4               NaN                 NaN
# 675               398743.4               100                 NaN
# 722              1606574.3                46                 NaN
# 1265             2468801.7               NaN                 NaN
# 746                    NaN                74       Not Available
# 214             43570400.6                44                 NaN
# 896             29305592.9                76                 NaN
# 738             18512976.3     Not Available       Not Available
# 808              5161400.6                61                 NaN
# 643                    NaN     Not Available       Not Available
# 79              75568157.1                83                 NaN
# 399                    NaN                64       Not Available
# 632              1900484.0                14                 NaN
# 668                    NaN                80       Not Available
# 871                    NaN     Not Available       Not Available
# 506                    NaN     Not Available       Not Available
# 217              3030628.1                 6                 NaN
# 542              7273077.2                75                 NaN
# 500             14198649.0                79                 NaN
# 669              4283476.0                80                 NaN
# 1171            35173864.4               NaN                 NaN
# 1491            38928634.0               NaN                 NaN
# 119                    NaN     Not Available       Not Available
# 933                    NaN     Not Available       Not Available
# 595              1895948.1     Not Available       Not Available
# 456              9751168.4                81       Not Available
#
#       fuel_oil_o2_use_kbtu              geom_address        lat        lng  \
# 908                    NaN     1801 North 9th Street  39.926824 -75.160476
# 687                    NaN                       NaN        NaN        NaN
# 1291                   NaN                       NaN        NaN        NaN
# 103                    NaN         801 Market Street  39.951193 -75.153667
# 1417                   NaN                       NaN        NaN        NaN
# 675                    NaN                       NaN        NaN        NaN
# 722                    NaN                       NaN        NaN        NaN
# 1265                   NaN                       NaN        NaN        NaN
# 746                    NaN         1501 W DIAMOND ST  39.984998 -75.158336
# 214              3631608.1                       NaN        NaN        NaN
# 896                    NaN                       NaN        NaN        NaN
# 738                    NaN                       NaN        NaN        NaN
# 808                    NaN                       NaN        NaN        NaN
# 643                    NaN      3201 Chestnut Street  39.953888 -75.187786
# 79                     NaN                       NaN        NaN        NaN
# 399                    NaN             4309 G Street  40.014243 -75.111667
# 632                    NaN                       NaN        NaN        NaN
# 668                    NaN        2001 Market Street  39.953613 -75.173291
# 871                    NaN  4641 Roosevelt Boulevard  40.028326 -75.100627
# 506                    NaN      495 E. Abington Ave.  40.076982 -75.196793
# 217              6703901.7                       NaN        NaN        NaN
# 542                    NaN                       NaN        NaN        NaN
# 500                    NaN                       NaN        NaN        NaN
# 669                    NaN                       NaN        NaN        NaN
# 1171             5067277.1                       NaN        NaN        NaN
# 1491                   NaN                       NaN        NaN        NaN
# 119                    NaN           1300 Adams Ave.  40.010471 -75.093514
# 933                    NaN        200 W. Chelten Ave  40.046543 -75.123484
# 595                    NaN                       NaN        NaN        NaN
# 456                    NaN                       NaN        NaN        NaN
#
#       ... steam_use_kbtu                   street_address  \
# 908   ...            NaN                              NaN
# 687   ...            NaN                   440 N BROAD ST
# 1291  ...            NaN                2950 KIRKBRIDE ST
# 103   ...            NaN                              NaN
# 1417  ...            NaN                   8875 RIDGE AVE
# 675   ...            NaN                  6225 OXFORD AVE
# 722   ...            NaN                    301 S 19TH ST
# 1265  ...            NaN             3605 GRAYS FERRY AVE
# 746   ...            NaN                              NaN
# 214   ...            NaN             5000 WISSAHICKON AVE
# 896   ...            NaN                  1400-30 ARCH ST
# 738   ...            NaN                              NaN
# 808   ...            NaN              1101 WASHINGTON AVE
# 643   ...            NaN                              NaN
# 79    ...     18616928.9                     1717 ARCH ST
# 399   ...            NaN                              NaN
# 632   ...            NaN            4401 CONSHOHOCKEN AVE
# 668   ...            NaN                              NaN
# 871   ...            NaN                              NaN
# 506   ...            NaN                              NaN
# 217   ...            NaN                  1197 HAWORTH ST
# 542   ...            NaN                  201-59 N 8TH ST
# 500   ...            NaN  500 N CHRISTOPHER COLUMBUS BLVD
# 669   ...            NaN           700 E HUNTING PARK AVE
# 1171  ...            NaN           3243 W SCHOOL HOUSE LN
# 1491  ...            NaN            1600 SPRING GARDEN ST
# 119   ...            NaN                              NaN
# 933   ...            NaN                              NaN
# 595   ...            NaN                              NaN
# 456   ...            NaN                              NaN
#
#                                                the_geom  \
# 908   0101000020E6100000D05A9B3D45CA52C058982628A2F6...
# 687                                                 NaN
# 1291                                                NaN
# 103   0101000020E6100000686473AFD5C952C0888EFEB3C0F9...
# 1417                                                NaN
# 675                                                 NaN
# 722                                                 NaN
# 1265                                                NaN
# 746   0101000020E6100000F48EB02E22CA52C00815DF6714FE...
# 214                                                 NaN
# 896                                                 NaN
# 738                                                 NaN
# 808                                                 NaN
# 643   0101000020E610000020AD05B104CC52C0484B1B0419FA...
# 79                                                  NaN
# 399   0101000020E6100000706DB48B25C752C0B063F9B3D201...
# 632                                                 NaN
# 668   0101000020E61000007CE9803317CB52C0D8FFB50010FA...
# 871   0101000020E610000040CE89AA70C652C0C054512EA003...
# 506   0101000020E610000080CCE73F98CC52C0C0DF8A8CDA09...
# 217                                                 NaN
# 542                                                 NaN
# 500                                                 NaN
# 669                                                 NaN
# 1171                                                NaN
# 1491                                                NaN
# 119   0101000020E61000008C8E4D20FCC552C090E7061F5701...
# 933   0101000020E6100000E0B3282BE7C752C0B0E56B22F505...
# 595                                                 NaN
# 456                                                 NaN
#
#                                    the_geom_webmercator  \
# 908   0101000020110F00009C4D717BBAEA5FC14B358C8B8485...
# 687                                                 NaN
# 1291                                                NaN
# 103   0101000020110F0000296A8AFEFCE95FC155C10D17F988...
# 1417                                                NaN
# 675                                                 NaN
# 722                                                 NaN
# 1265                                                NaN
# 746   0101000020110F0000FA83A4EE7EEA5FC142BC8D9BC48D...
# 214                                                 NaN
# 896                                                 NaN
# 738                                                 NaN
# 808                                                 NaN
# 643   0101000020110F00008C16C185B2ED5FC1C5F4E0EE5A89...
# 79                                                  NaN
# 399   0101000020110F00001CEAB01E6CE55FC10D8EAA0CEB91...
# 632                                                 NaN
# 668   0101000020110F00005C090D1F1FEC5FC1828170F25089...
# 871   0101000020110F00002DC7B4E038E45FC184BE77D7EA93...
# 506   0101000020110F00004DDB312AADEE5FC1C041EBDAD39A...
# 217                                                 NaN
# 542                                                 NaN
# 500                                                 NaN
# 669                                                 NaN
# 1171                                                NaN
# 1491                                                NaN
# 119   0101000020110F0000235841EC72E35FC14B13FA026291...
# 933   0101000020110F00008BFBFF01B5E65FC1118077098196...
# 595                                                 NaN
# 456                                                 NaN
#
#       total_floor_area_bld_pk_ft2  total_ghg_emissions_mtco2e  \
# 908                           NaN                         1.3
# 687                      835000.0                      4461.1
# 1291                     256000.0                       461.7
# 103                           NaN                      4288.1
# 1417                      71040.0                         5.5
# 675                      103528.0                        53.4
# 722                       78750.0                       454.9
# 1265                      80785.0                       317.1
# 746                           NaN                       478.2
# 214                      449021.0                      5153.7
# 896                      491000.0                      3807.1
# 738                           NaN                      5401.5
# 808                      180000.0                       683.8
# 643                           NaN                      6492.8
# 79                      1377698.0                      9902.3
# 399                           NaN                       179.5
# 632                       80000.0                       482.8
# 668                           NaN                      8901.8
# 871                           NaN                      5645.4
# 506                           NaN                         NaN
# 217                       65570.0                       864.6
# 542                      167542.0                       917.0
# 500                      335538.0                      1912.7
# 669                       82617.0                       573.4
# 1171                     635839.0                      5375.9
# 1491                     524198.0                      3946.1
# 119                           NaN                         NaN
# 933                           NaN                       272.6
# 595                           NaN                       417.7
# 456                           NaN                      1784.6
#
#       water_use_all_kgal water_use_all_water_sources_kgal  year year_built
# 908                  NaN                              0.0  2013       1900
# 687               5055.9                              NaN  2015       2005
# 1291               373.9                              NaN  2016       1963
# 103                  NaN                           9039.9  2013       1909
# 1417                 3.8                              NaN  2017       1980
# 675                 51.0                              NaN  2015       2000
# 722               2005.5                              NaN  2016       1933
# 1265               587.6                              NaN  2017       1984
# 746                  NaN                            362.7  2013       1968
# 214               9108.5                              NaN  2017       1998
# 896               3384.7                              NaN  2017       1968
# 738                  NaN                           3134.8  2014       2000
# 808               4206.3                              NaN  2016       1935
# 643                  NaN                           6480.7  2013       1898
# 79               18111.8                              NaN  2016       1990
# 399                  NaN                            807.0  2013       1950
# 632                427.1                              NaN  2016       1931
# 668                  NaN                          19881.4  2013       1992
# 871                  NaN                          13832.7  2013       1950
# 506                  NaN                              NaN  2013       1970
# 217                890.2                              NaN  2016       1923
# 542               6837.2                              NaN  2016       2005
# 500               2938.3                              NaN  2015       1891
# 669                619.2                              NaN  2015       1990
# 1171             31036.7                              NaN  2016       1960
# 1491                 NaN                              NaN  2017       1982
# 119                  NaN                             18.4  2013       1929
# 933                  NaN                           2319.2  2013       1990
# 595                  NaN                           1109.8  2014       1970
# 456                  NaN                           2037.7  2014       1927
#
# [30 rows x 38 columns]

# %%
full_df['building_id'].value_counts().value_counts(sort=False)
# Out:
# 1    192
# 2    560
# 3    183
# 4    329
# 5    542
# Name: building_id, dtype: int64

# %%
full_df.shape
# Out:
# (5887, 38)

# %% [markdown]
# <div class="alert alert-warning">
#     <li><code>full_df</code> has all dataframes combined - be still need to rename the columns</li>
#     <li>But for now can use it to get unique building ids and street addresses that need then to have geo lookup</li>
# </div>

# %%
full_df.columns
# Out:
# Index(['building_id', 'district_steam_use_kbtu',
#        'electricity_use_grid_purchase_and_generated_from_onsite_renewab',
#        'electricity_use_kbtu', 'energy_star_score', 'fuel_oil_2_use_kbtu',
#        'fuel_oil_o2_use_kbtu', 'geom_address', 'lat', 'lng',
#        'location_1_address', 'natural_gas_use_kbtu', 'notes',
#        'num_of_buildings', 'number_of_buildings', 'objectid',
#        'portfolio_manager_id', 'postal_code', 'primary_prop_type_epa_calc',
#        'primary_property_type_epa_calculated',
#        'property_floor_area_buildings_and_parking_ft', 'property_name',
#        'site_eui_kbtu_ft', 'site_eui_kbtu_ft2', 'site_eui_kbtuft2',
#        'source_eui_kbtu_ft', 'source_eui_kbtu_ft2', 'source_eui_kbtuft2',
#        'steam_use_kbtu', 'street_address', 'the_geom', 'the_geom_webmercator',
#        'total_floor_area_bld_pk_ft2', 'total_ghg_emissions_mtco2e',
#        'water_use_all_kgal', 'water_use_all_water_sources_kgal', 'year',
#        'year_built'],
#       dtype='object')

# %%
building_ids = full_df['building_id'].value_counts().reset_index()
building_ids.head()
# Out:
#        index  building_id
# 0  882055181            5
# 1  786154910            5
# 2  884130000            5
# 3  883704600            5
# 4  884267500            5

# %%
rows_without_geo=full_df[full_df['lat'].isnull()]

# %%
rows_without_geo.shape
# Out:
# (4938, 38)

# %%
rows_without_geo['building_id'].nunique()
# Out:
# 1757

# %% [markdown]
# <div class="alert alert-info">
#     <li>So there are 1757 buildings that need to have geolookup</li>
#     <li>Need to get building_id and street address from appropriate columns into a new list</li>
#     <li>Write this list to another file and then do batches of lookup</li>
#     <li>Then can merge all the data back together</li>
# </div>

# %%
rows_to_geolookup=rows_without_geo.drop_duplicates(subset=['building_id'])

# %%
rows_to_geolookup.shape
# Out:
# (1757, 38)

# %%
rows_to_geolookup.columns
# Out:
# Index(['building_id', 'district_steam_use_kbtu',
#        'electricity_use_grid_purchase_and_generated_from_onsite_renewab',
#        'electricity_use_kbtu', 'energy_star_score', 'fuel_oil_2_use_kbtu',
#        'fuel_oil_o2_use_kbtu', 'geom_address', 'lat', 'lng',
#        'location_1_address', 'natural_gas_use_kbtu', 'notes',
#        'num_of_buildings', 'number_of_buildings', 'objectid',
#        'portfolio_manager_id', 'postal_code', 'primary_prop_type_epa_calc',
#        'primary_property_type_epa_calculated',
#        'property_floor_area_buildings_and_parking_ft', 'property_name',
#        'site_eui_kbtu_ft', 'site_eui_kbtu_ft2', 'site_eui_kbtuft2',
#        'source_eui_kbtu_ft', 'source_eui_kbtu_ft2', 'source_eui_kbtuft2',
#        'steam_use_kbtu', 'street_address', 'the_geom', 'the_geom_webmercator',
#        'total_floor_area_bld_pk_ft2', 'total_ghg_emissions_mtco2e',
#        'water_use_all_kgal', 'water_use_all_water_sources_kgal', 'year',
#        'year_built'],
#       dtype='object')

# %%
[c for c in rows_to_geolookup.columns if c.count('address')>0 or c.count('code')>0]
# Out:
# ['geom_address', 'location_1_address', 'postal_code', 'street_address']

# %%
to_lookup=rows_to_geolookup[['building_id',
                  'location_1_address', 'street_address', 'postal_code']]

to_lookup.loc[to_lookup['street_address'].isnull(), 'street_address'] = to_lookup[to_lookup['street_address'].isnull()]['location_1_address']
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
to_lookup.drop(columns=['location_1_address'], inplace=True)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
to_lookup['lat']=None
to_lookup['lng']=None
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
to_lookup.sample(20)
# Out:
#       building_id                  street_address postal_code   lat   lng
# 757     881822370                 4035 PARRISH ST       19104  None  None
# 900     886662700                6300 OLD YORK RD       19141  None  None
# 690     884249500               4219 Van Kirk St.       19135  None  None
# 901     881551130           1901-39 CALLOWHILL ST       19130  None  None
# 992     888058983                  1401 WALNUT ST       19102  None  None
# 545     883743000             8900 Bartram Avenue       19153  None  None
# 460     784615800               2700 W DAUPHIN ST       19132  None  None
# 994     782513700          2600 Ben Franklin Pkwy       19130  None  None
# 551     771635100                447 N. Broad St.       19123  None  None
# 858     786482200                   3001 RYAN AVE       19152  None  None
# 322     884091000                 1300 Adams Ave.       19124  None  None
# 492     881426260                3231-65 N 2ND ST       19140  None  None
# 337     883038000                 1435 Walnut St.       19102  None  None
# 383     882920201                  1500 N 50TH ST       19131  None  None
# 446     782425810  2025 Benjamin Franklin Parkway       19130  None  None
# 1024    881443292            1440 MOUNT VERNON ST       19130  None  None
# 14      774526000           3118-38 Market Street       19104  None  None
# 583     784378200                  6498 RIDGE AVE       19128  None  None
# 720     888111280                 2200-28 ARCH ST       19103  None  None
# 675     881063000            5553 WISSAHICKON AVE       19144  None  None

# %%
to_lookup.to_csv('../data/buildings_needing_geoinfo.csv', index=False)

# %% [markdown]
# ## Do geolookup for buildings missing lat and long in the datasheets
#
# * Now can use the `to_lookup` data frame which is a unique list of building ids to do geolookup
#
# ### Setup `lookup` object

# %%
geolocator = Nominatim(user_agent="application")
lookup = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
def geo_code_selection(df, sample_size=1577):
    
    need_coding = df[(df['lat'].isnull()) & (df['lng'].isnull())]
    
    print('There are {} buildings to code'.format(need_coding.shape[0]))
    
    print('\nSelecting {} to code'.format(sample_size))
    
    to_code = need_coding.sample(sample_size)

    for row in to_code.to_dict(orient='records'):

        building_id=row['building_id']


        street = row['street_address'].title()

        street = re.sub('^(\d+)-\d+','\\1', street)

        zip = str(int(row['postal_code']))

        address = "{}, PA {}".format(street, zip)

        print(address)
        location = lookup(address, language='en', exactly_one=True)

        try:
            lat=location.latitude
            lng=location.longitude
            df.loc[df['building_id']==building_id,'lat']=lat
            df.loc[df['building_id']==building_id,'lng']=lng
        except:
            print("Couldn't find geolocation")

# %%
geo_code_selection(to_lookup, sample_size=100)
to_lookup.to_csv('../data/buildings_needing_geoinfo.csv', index=False)
# Out:
# There are 1757 buildings to code
#
# Selecting 100 to code
# 1520 Locust Street, PA 19102
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 7400 Holstein Ave., PA 19153
# 1201 Washington Ave, PA 19147
# 725 South 5Th St, PA 19147
# 5000 Oxford Ave, PA 19124
# 2100 Kubach Road, PA 19116
# 1327 Locust St, PA 19107
# 1666 Callowhill St, PA 19130
# 6498 Ridge Ave, PA 19128
# 3615 Market St., PA 19104
# 2901 S 10Th Street, PA 19148
# 521 S Broad St, PA 19147
# 2017 Chestnut St, PA 19103
# 600 N 34Th St, PA 19104
# 1751 Callowhill St, PA 19130
# 1651 Christopher Columbus Blvd, PA 19148
# 1700 Bigler St, PA 19145
# 160 E Erie Ave, PA 19134
# 5400 E Roosevelt Blvd, PA 19124
# Couldn't find geolocation
# 108 Arch St, PA 19106
# 1821 E Hagert St, PA 19125
# 20 S 36Th St, PA 19104
# 2967 W School House Ln, PA 19144
# 5720 Media St, PA 19131
# 4901 Rising Sun Ave, PA 19120
# 833 Chestnut Street, PA 19107
# 201 Sunset Ave, PA 19118
# 5675 Rising Sun Ave, PA 19120
# 626 Dickinson St, PA 19147
# 1007 W. Lehigh Avenue, PA 19133
# 301 Race St, PA 19106
# 4901 Stenton Ave, PA 19144
# 1508 W Allegheny Ave, PA 19132
# 7100 Henry Ave, PA 19128
# 11620 Caroline Rd., PA 19154
# 5515 Wissahickon Ave, PA 19144
# 13500 E Roosevelt Blvd, PA 19116
# Couldn't find geolocation
# 319 W Chelten Ave, PA 19144
# 2020 N. 13Th, PA 19122
# Couldn't find geolocation
# 5014 Grays Avenue, PA 19143
# 1800 Byberry Rd, PA 19116
# 3899 Richmond St, PA 19137
# 1400 East Erie Avenue, PA 19124
# 1200 E. Erie Avenue, PA 19124
# 6401 Horrocks St, PA 19149
# 3200 B St, PA 19134
# 1701 Market St, PA 19103
# 9898 Roosevelt Blvd., PA 19115
# 3600 Conshohocken Ave, PA 19131
# 945 N Franklin St, PA 19123
# 3400 Civic Center Blvd, PA 19104
# 3515 Amber Street, PA 19134
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4d29897e2320> in <module>()
# ----> 1 geo_code_selection(to_lookup, sample_size=100)
#       2 to_lookup.to_csv('../data/buildings_needing_geoinfo.csv', index=False)
#
# <ipython-input-26-d35b5141f5a1> in geo_code_selection(df, sample_size)
#      18         street = re.sub('^(\d+)-\d+','\\1', street)
#      19
# ---> 20         zip = str(int(row['postal_code']))
#      21
#      22         address = "{}, PA {}".format(street, zip)
#
# ValueError: invalid literal for int() with base 10: '19126-2233'

# %%
to_lookup
# Out:
#       building_id             street_address postal_code      lat      lng
# 0       785548000            450 W NEDRO AVE       19120     None     None
# 1       884240500            10814 NE AVENUE       19116     None     None
# 2       884114205               4123 "G" St.       19124     None     None
# 3       784463600                4667 UMBRIA       19143     None     None
# 4       784378000             6000 RIDGE AVE       19128     None     None
# 5       783183400          5001 GREENWAY AVE       19143     None     None
# 6       783087800             6001 CEDAR AVE       19143     None     None
# 7       883359300    1163-65 S. BROAD STREET       19147     None     None
# 8       883013200        117-31 N 8th Street       19106     None     None
# 9       882167505        6701 Essingtion ave       19153     None     None
# 10      771500000  329-35 South Broad Street       19102     None     None
# 11      772505410  201-11 South Broad Street       19107     None     None
# 12      771637200  401-11 South Broad Street       19147     None     None
# 13      775501010             4201 Henry Ave       19144     None     None
# 14      774526000      3118-38 Market Street       19104     None     None
# 15      774517051  3200-3246 Chestnut Street       19104     None     None
# 16      774517200    3250-60 Chestnut Street       19104     None     None
# 17      774528000      3201-47 Market Street       19104     None     None
# 18      774530700    3300-3350 Market Street       19104     None     None
# 19      774525000      3100-16 Market Street       19104     None     None
# 20      774513500        3201-21 Arch Street       19104     None     None
# 21      882065510        2327-83 Cottman Ave       19149     None     None
# 22      772521000      1920-1934 Race Street       19103     None     None
# 23      773500500          4247 Woodland Ave       19104     None     None
# 24      777572705            1449 C.B. MOORE       19121     None     None
# 25      777508500       1800-38 N. Broad St.       19122     None     None
# 26      777570000            1301 C.B. MOORE       19122     None     None
# 27      777540000            1301 C.B. MOORE       19122     None     None
# 28      777528500          3307 N. Broad St.       19140     None     None
# 29      776515000          1924 W Olney Ave.       19144     None     None
# ...           ...                        ...         ...      ...      ...
# 818     881041751         1221 FAIRMOUNT AVE       19123     None     None
# 819     886810736    1727 W HUNTING PARK AVE       19139     None     None
# 821     881064600            5008 MCKEAN AVE       19144     None     None
# 830     881445700         4401 HAVERFORD AVE       19104     None     None
# 869     881170500         7801 BUSTLETON AVE       19152     None     None
# 919     886652600      4400-58 FAIRMOUNT AVE       19104     None     None
# 941     888570101              2628 WELSH RD       19152     None     None
# 948     886653901       1900 W ALLEGHENY AVE       19119     None     None
# 950     881439770        6150-52 W OXFORD ST       19151     None     None
# 1017    886766100        2663 W GLENWOOD AVE       19121     None     None
# 1025    881007026          259 MARKET ST # 2       19106     None     None
# 1060    881162530     4000 PRESIDENTIAL BLVD       19131     None     None
# 1067    881085500       5720 WISSAHICKON AVE       19144     None     None
# 1074    881561900              450 N 18TH ST       19130     None     None
# 1085    881576550             777 S BROAD ST       19147     None     None
# 1091    881576560          521-31 S BROAD ST       19147  39.9439 -75.1653
# 1359    881561625   1818-20 SPRING GARDEN ST       19130     None     None
# 1370    881025000             1849 WALNUT ST       19103     None     None
# 1400    881094500       1300-20 E JOHNSON ST       19138     None     None
# 1406    881215700          4701-23 WALNUT ST       19143     None     None
# 1438    883102000           716-30 SPRUCE ST       19106     None     None
# 1448    884217000          5331-37 N 10TH ST       19141     None     None
# 1516    883422500          2027-39 SANSOM ST       19103     None     None
# 1521    781050600         500-36 CHESTNUT ST       19106     None     None
# 1525    884579100       1826-70 W LEHIGH AVE       19132     None     None
# 1529    883523100       990 SPRING GARDEN ST       19123     None     None
# 1531    881068611          410-26 MEMPHIS ST       19125     None     None
# 1541    881178500            2400 TREMONT ST       19115     None     None
# 1542    881179000            2318 TREMONT ST       19115     None     None
# 1550    881178000           2393 WOODWARD ST       19115     None     None
#
# [1757 rows x 5 columns]

# %%
astr='1147 N 4Th St, PA 19123'

location = lookup(astr, language='en', exactly_one=True)
location

# %% [markdown]
# Location(1147, North 4th Street, Olde Kensington, Philadelphia, Philadelphia County, Pennsylvania, 19123, United States of America, (39.968576244898, -75.143281755102, 0.0))
