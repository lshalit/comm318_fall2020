# %%
# %matplotlib inline
import pandas as pd

# %%
pd.read_csv('../data/enrollment_demographics.csv')
# Out:
#      School Year  SRC School ID                                  School Name  \
# 0      2018-2019            101                     John Bartram High School
# 1      2018-2019            101                     John Bartram High School
# 2      2018-2019            101                     John Bartram High School
# 3      2018-2019            101                     John Bartram High School
# 4      2018-2019            101                     John Bartram High School
# 5      2018-2019            102                West Philadelphia High School
# 6      2018-2019            102                West Philadelphia High School
# 7      2018-2019            102                West Philadelphia High School
# 8      2018-2019            102                West Philadelphia High School
# 9      2018-2019            102                West Philadelphia High School
# 10     2018-2019            103                    High School of the Future
# ...

# %% [markdown]
# * This first file contains a running list of all of the schools in the Philadelphia School District.  Each of these schools are divided into a row for "All Grades" and a row for each of the grades that are served.

# %%
enrollment_demographics = pd.read_csv('../data/enrollment_demographics.csv')

# %%
enrollment_demographics.shape
# Out:
# (1673, 33)

# %%
enrollment_demographics.count()
# Out:
# School Year                            1673
# SRC School ID                          1673
# School Name                            1673
# Learning Network                       1673
# Grade Level                            1673
# Student Enrollment                     1673
# ELL Count                              1673
# ELL Pct                                1673
# Not ELL Count                          1673
# Not ELL Pct                            1673
# IEP Count                              1673
# IEP Pct                                1673
# Not IEP Count                          1673
# Not IEP Pct                            1673
# Female Count                           1673
# Female Pct                             1673
# Male Count                             1673
# Male Pct                               1673
# American Indian Count                  1673
# American Indian Pct                    1673
# Asian Count                            1673
# ...

# %% [markdown]
# * Note:
#     * CEP = "Community Eligibility Provision"
#     * IEP = "Individualized Education Program"
#     * ELL = "English Language Learner"

# %%
enrollment_demographics.columns
# Out:
# Index(['School Year', 'SRC School ID', 'School Name', 'Learning Network',
#        'Grade Level', 'Student Enrollment', 'ELL Count', 'ELL Pct',
#        'Not ELL Count', 'Not ELL Pct', 'IEP Count', 'IEP Pct', 'Not IEP Count',
#        'Not IEP Pct', 'Female Count', 'Female Pct', 'Male Count', 'Male Pct',
#        'American Indian Count', 'American Indian Pct', 'Asian Count',
#        'Asian Pct', 'Black/African American Count',
#        'Black/African American Pct', 'Hispanic Count', 'Hispanic Pct',
#        'Multi-Race Count', 'Multi-Race Pct', 'Pacific Islander Count',
#        'Pacific Islander Pct', 'White Count', 'White Pct',
#        'CEP Economically Disadvantaged Rate'],
#       dtype='object')

# %%
enrollment_demographics.head()
# Out:
#   School Year  SRC School ID               School Name Learning Network  \
# 0   2018-2019            101  John Bartram High School       Network 13
# 1   2018-2019            101  John Bartram High School       Network 13
# 2   2018-2019            101  John Bartram High School       Network 13
# 3   2018-2019            101  John Bartram High School       Network 13
# 4   2018-2019            101  John Bartram High School       Network 13
#
#   Grade Level  Student Enrollment  ELL Count  ELL Pct  Not ELL Count  \
# 0          09                 142          7     4.93            135
# 1          10                 145         10     6.90            135
# 2          11                 153         11     7.19            142
# 3          12                  94          9     9.57             85
# 4  All Grades                 534         37     6.93            497
#
#    Not ELL Pct  ...  Black/African American Pct  Hispanic Count  Hispanic Pct  \
# ...

# %%
enrollment_demographics.tail()
# Out:
#      School Year  SRC School ID                   School Name  \
# 1668   2018-2019            878  Philadelphia Virtual Academy
# 1669   2018-2019            878  Philadelphia Virtual Academy
# 1670   2018-2019            878  Philadelphia Virtual Academy
# 1671   2018-2019            878  Philadelphia Virtual Academy
# 1672   2018-2019            878  Philadelphia Virtual Academy
#
#      Learning Network Grade Level  Student Enrollment  ELL Count  ELL Pct  \
# 1668       Innovation          09                  85          1     1.18
# 1669       Innovation          10                 115          1     0.87
# 1670       Innovation          11                 129          3     2.33
# 1671       Innovation          12                 163          3     1.84
# 1672       Innovation  All Grades                 551         10     1.81
#
#       Not ELL Count  Not ELL Pct  ...  Black/African American Pct  \
# 1668             84        98.82  ...                       69.41
# ...

# %%
enrollment_demographics.sample()
# Out:
#      School Year  SRC School ID          School Name Learning Network  \
# 1652   2018-2019            856  The Workshop School       Innovation
#
#      Grade Level  Student Enrollment  ELL Count  ELL Pct  Not ELL Count  \
# 1652          11                  52          1     1.92             51
#
#       Not ELL Pct  ...  Black/African American Pct  Hispanic Count  \
# 1652        98.08  ...                       82.69               1
#
#       Hispanic Pct  Multi-Race Count  Multi-Race Pct  Pacific Islander Count  \
# 1652          1.92                 4            7.69                       1
#
#       Pacific Islander Pct  White Count  White Pct  \
# 1652                  1.92            2       3.85
#
#       CEP Economically Disadvantaged Rate
# 1652                                    .
#
# [1 rows x 33 columns]

# %% [markdown]
# * Ran a few basic codes in order to get a sense of what the data looked like and get more familiar working with it.

# %%
enrollment_demographics['School Name'].describe()
# Out:
# count                        1673
# unique                        215
# top       Widener Memorial School
# freq                           14
# Name: School Name, dtype: object

# %%
enrollment_demographics['School Name'].value_counts()
# Out:
# Widener Memorial School                                    14
# William M. Meredith School                                 10
# John Welsh School                                          10
# John F. Hartranft School                                   10
# James Dobson School                                        10
# Laura W. Waring School                                     10
# John Barry School                                          10
# John F. McCloskey School                                   10
# Andrew Hamilton School                                     10
# General George A. McCall School                            10
# Chester A. Arthur School                                   10
# Albert M. Greenfield School                                10
# Lewis C. Cassidy Academics Plus School                     10
# Joseph Greenberg School                                    10
# Overbrook School                                           10
# ...

# %% [markdown]
# * Each school shows multiple values because each school is broken down by each grade, that is served, along with having a section for "All Grades". Which is why a school like Widener Memorial School has 14 values, because it serves grades K-12.

# %%
enrollment_demographics['Learning Network'].value_counts()
# Out:
# Acceleration    171
# Network 3       160
# Network 6       151
# Network 8       138
# Network 2       131
# Network 5       128
# Network 9       127
# Network 7       119
# Network 12       98
# Network 1        95
# Network 4        95
# Network 11       91
# Network 10       88
# Innovation       46
# Network 13       35
# Name: Learning Network, dtype: int64

# %% [markdown]
# * Each school in the district is sectioned off into a different "Network".  These networks are marked "1-13", "Acceleration", "Innovation".  Charter schools however are not included in this data file.

# %%
enrollment_demographics['Learning Network'].describe()
# Out:
# count             1673
# unique              15
# top       Acceleration
# freq               171
# Name: Learning Network, dtype: object

# %%
enrollment_demographics.plot()

# %% [markdown]
# * I attempted to see what the data spread would look like if I were to plot the entire file.

# %% [markdown]
# * I tried to completely clean this file multiple times and upload it, but it still won't upload onto the Notebook completely "clean".  The bottom values are blank spaces, and don't represent any schools.  But, all of the Philadelphia schools are listed here along with their respective attendance rates.

# %%
pd.read_csv('../data/upd_95_attendance_yearly.csv')
# Out:
#      School Year  ULCS Code                    School Name  Grade    Sector  \
# 0      2017-2018     1010.0      Bartram, John High School    9.0  District
# 1      2017-2018     1010.0      Bartram, John High School   10.0  District
# 2      2017-2018     1010.0      Bartram, John High School   11.0  District
# 3      2017-2018     1010.0      Bartram, John High School   12.0  District
# 4      2017-2018     1020.0  West Philadelphia High School    9.0  District
# 5      2017-2018     1020.0  West Philadelphia High School   10.0  District
# 6      2017-2018     1020.0  West Philadelphia High School   11.0  District
# 7      2017-2018     1020.0  West Philadelphia High School   12.0  District
# 8      2017-2018     1030.0      High School of the Future    9.0  District
# 9      2017-2018     1030.0      High School of the Future   10.0  District
# 10     2017-2018     1030.0      High School of the Future   11.0  District
# ...

# %% [markdown]
# * This file looks at all of the schools in the district, the percentage, and corresponding number of students, that have attended 95% or more of instructional school days.  This file breaks down the percentages by school and then by grade.

# %%
hs_yearly_attendance = pd.read_csv('../data/upd_95_attendance_yearly.csv')

# %%
hs_yearly_attendance.shape
# Out:
# (5745, 8)

# %%
hs_yearly_attendance.count()
# Out:
# School Year                        5706
# ULCS Code                          5706
# School Name                        5706
# Grade                              5706
# Sector                             5706
# % with 95%+ Attendance (Yearly)    5706
# # with 95%+ Attendance (Yearly)    5706
# Total Students (Yearly)            5706
# dtype: int64

# %%
hs_yearly_attendance.columns
# Out:
# Index(['School Year', 'ULCS Code', 'School Name', 'Grade', 'Sector',
#        '% with 95%+ Attendance (Yearly)', '# with 95%+ Attendance (Yearly)',
#        'Total Students (Yearly)'],
#       dtype='object')

# %%
hs_yearly_attendance.head()
# Out:
#   School Year  ULCS Code                    School Name  Grade    Sector  \
# 0   2017-2018     1010.0      Bartram, John High School    9.0  District
# 1   2017-2018     1010.0      Bartram, John High School   10.0  District
# 2   2017-2018     1010.0      Bartram, John High School   11.0  District
# 3   2017-2018     1010.0      Bartram, John High School   12.0  District
# 4   2017-2018     1020.0  West Philadelphia High School    9.0  District
#
#   % with 95%+ Attendance (Yearly)  # with 95%+ Attendance (Yearly)  \
# 0                           22.8%                             46.0
# 1                           31.9%                             69.0
# 2                           27.6%                             42.0
# 3                           22.1%                             38.0
# 4                           12.8%                             19.0
#
#   Total Students (Yearly)
# 0                     202
# 1                     216
# 2                     152
# ...

# %%
hs_yearly_attendance.sample()
# Out:
#      School Year  ULCS Code                   School Name  Grade    Sector  \
# 1641   2016-2017     2020.0  Creative and Performing Arts   10.0  District
#
#      % with 95%+ Attendance (Yearly)  # with 95%+ Attendance (Yearly)  \
# 1641                           41.8%                             82.0
#
#      Total Students (Yearly)
# 1641                     196

# %%
hs_yearly_attendance['% with 95%+ Attendance (Yearly)'].value_counts()
# Out:
# 33.3%    68
# 50.0%    46
# 40.0%    36
# 25.0%    33
# 44.4%    27
# 28.6%    26
# 37.5%    26
# 42.9%    26
# 32.8%    26
# 45.2%    23
# 30.8%    23
# 33.8%    22
# 32.4%    22
# 35.7%    21
# 47.1%    21
# 60.0%    20
# 41.1%    20
# 48.4%    20
# 36.7%    20
# 34.0%    20
# 41.7%    20
# 47.5%    19
# 34.8%    19
# 40.5%    19
# 43.1%    19
# 37.9%    19
# 29.3%    19
# 20.0%    19
# 41.4%    19
# 55.3%    19
#          ..
# 85.5%     1
# 89.8%     1
# 6.8%      1
# 93.9%     1
# 68.7%     1
# 80.4%     1
# 74.1%     1
# 6.2%      1
# 0.7%      1
# 7.3%      1
# 89.6%     1
# 75.3%     1
# 80.8%     1
# 67.8%     1
# 64.5%     1
# 13.6%     1
# 2.0%      1
# 82.3%     1
# 86.5%     1
# 7.9%      1
# 72.6%     1
# 79.3%     1
# 25.1%     1
# 75.9%     1
# 80.2%     1
# 61.9%     1
# 86.2%     1
# 85.8%     1
# 21.2%     1
# 84.2%     1
# Name: % with 95%+ Attendance (Yearly), Length: 816, dtype: int64

# %% [markdown]
# * Here I wanted to get a look at what percentage of students attending more than 95% of instructional days was across each school.  Using .value_counts() we can see that 68 schools had 33%, while 46 schools were able to reach 50%.

# %%
hs_yearly_attendance['% with 95%+ Attendance (Yearly)'].describe()
# Out:
# count      5706
# unique      816
# top       33.3%
# freq         68
# Name: % with 95%+ Attendance (Yearly), dtype: object

# %%
hs_yearly_attendance['# with 95%+ Attendance (Yearly)'].value_counts()
# Out:
# 22.0     159
# 21.0     150
# 25.0     148
# 19.0     146
# 18.0     143
# 20.0     142
# 17.0     142
# 16.0     138
# 23.0     138
# 14.0     137
# 29.0     133
# 27.0     125
# 30.0     124
# 28.0     121
# 15.0     118
# 26.0     117
# 34.0     116
# 24.0     113
# 13.0     111
# 33.0     105
# 12.0     105
# 31.0      98
# 38.0      92
# 32.0      90
# 11.0      88
# 40.0      84
# 39.0      84
# 35.0      82
# 44.0      81
# 37.0      80
#         ...
# 254.0      1
# 474.0      1
# 152.0      1
# 272.0      1
# 464.0      1
# 184.0      1
# 189.0      1
# 431.0      1
# 262.0      1
# 138.0      1
# 252.0      1
# 148.0      1
# 196.0      1
# 344.0      1
# 449.0      1
# 239.0      1
# 370.0      1
# 247.0      1
# 218.0      1
# 142.0      1
# 155.0      1
# 411.0      1
# 245.0      1
# 243.0      1
# 592.0      1
# 180.0      1
# 408.0      1
# 496.0      1
# 188.0      1
# 191.0      1
# Name: # with 95%+ Attendance (Yearly), Length: 221, dtype: int64

# %% [markdown]
# * Similarly to the analysis of "% with 95%+ Attendance" I wanted to see what the breakdown was, but with the number of students as opposed to the percentage.  Here there were 159 schools that had 22 students who were able to attend more than 95% of instructional days.
