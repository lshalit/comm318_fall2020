# %%
# %matplotlib inline
import pandas as pd

# %% [markdown]
# * This file contains a running list of all of the schools in the Philadelphia School District.  Each of these schools is divided into a row for "All Grades" and a row for each of the grades served.

# %%
enrollment_demographics = pd.read_csv('../data/enrollment_demographics.csv')

# %%
print(enrollment_demographics.columns)
# Out:
# Index(['School Year', 'SRC School ID', 'School Name', 'Learning Network',
#        'Grade Level', 'Student Enrollment', 'ELL Count', 'ELL Pct',
#        'Not ELL Count', 'Not ELL Pct', 'IEP Count', 'IEP Pct', 'Not IEP Count',
#        'Not IEP Pct', 'Female Count', 'Female Pct', 'Male Count', 'Male Pct',
#        'American Indian Count', 'American Indian Pct', 'Asian Count',
#        'Asian Pct', 'Black/African American Count',
#        'Black/African American Pct', 'Hispanic Count', 'Hispanic Pct',
#        'Multi-Race Count', 'Multi-Race Pct', 'Pacific Islander Count',
#        'Pacific Islander Pct', 'White Count', 'White Pct',
#        'CEP Economically Disadvantaged Rate'],
#       dtype='object')

# %%
enrollment_demographics.shape
# Out:
# (1673, 33)

# %%
enrollment_demographics.describe
# Out:
# <bound method NDFrame.describe of      School Year  SRC School ID                                  School Name  \
# 0      2018-2019            101                     John Bartram High School
# 1      2018-2019            101                     John Bartram High School
# 2      2018-2019            101                     John Bartram High School
# 3      2018-2019            101                     John Bartram High School
# 4      2018-2019            101                     John Bartram High School
# 5      2018-2019            102                West Philadelphia High School
# 6      2018-2019            102                West Philadelphia High School
# 7      2018-2019            102                West Philadelphia High School
# 8      2018-2019            102                West Philadelphia High School
# 9      2018-2019            102                West Philadelphia High School
# 10     2018-2019            103                    High School of the Future
# ...

# %%
enrollment_demographics[['School Name','Grade Level','Student Enrollment']]
# Out:
#                                       School Name Grade Level  \
# 0                        John Bartram High School          09
# 1                        John Bartram High School          10
# 2                        John Bartram High School          11
# 3                        John Bartram High School          12
# 4                        John Bartram High School  All Grades
# 5                   West Philadelphia High School          09
# 6                   West Philadelphia High School          10
# 7                   West Philadelphia High School          11
# 8                   West Philadelphia High School          12
# 9                   West Philadelphia High School  All Grades
# 10                      High School of the Future          09
# 11                      High School of the Future          10
# 12                      High School of the Future          11
# 13                      High School of the Future          12
# ...

# %% [markdown]
# * Here I wanted to get an idea of the enrollment of students at each school and within each grade. I think it is important to keep in mind the number of students that attend each school in order to better analyze the influence that school size may have.

# %% [markdown]
# * This file is an edited version of the Enrollment/Demographics file that was uploaded above.  I streamlined the original data set to just show the 65 schools that are within a three mile radius of Penn's campus.

# %%
penn_phl_schools = pd.read_csv('../data/penn_phl_school_ed.csv')

# %%
penn_phl_schools.shape
# Out:
# (66, 33)

# %%
penn_phl_schools.describe()
# Out:
#        SRC School ID  Student Enrollment   ELL Count    ELL Pct  \
# count      66.000000           66.000000   66.000000  66.000000
# mean      255.590909          479.090909   38.015152   7.029394
# std       159.736030          196.900344   66.661370  10.229636
# min       101.000000          169.000000    0.000000   0.000000
# 25%       137.250000          358.500000    3.000000   0.635000
# 50%       230.500000          454.000000    9.000000   2.025000
# 75%       264.750000          546.750000   44.500000  10.020000
# max       878.000000         1213.000000  373.000000  45.930000
#
#        Not ELL Count  Not ELL Pct   IEP Count    IEP Pct  Not IEP Count  \
# count      66.000000    66.000000   66.000000  66.000000      66.000000
# mean      441.075758    92.970606   69.803030  16.456061     409.287879
# std       183.033525    10.229636   37.889402   8.959386     203.378598
# min       169.000000    54.070000   10.000000   0.820000     110.000000
# ...

# %%
penn_phl_schools.columns
# Out:
# Index(['School Year', 'SRC School ID', 'School Name', 'Learning Network',
#        'Grade Level', 'Student Enrollment', 'ELL Count', 'ELL Pct',
#        'Not ELL Count', 'Not ELL Pct', 'IEP Count', 'IEP Pct', 'Not IEP Count',
#        'Not IEP Pct', 'Female Count', 'Female Pct', 'Male Count', 'Male Pct',
#        'American Indian Count', 'American Indian Pct', 'Asian Count',
#        'Asian Pct', 'Black/African American Count',
#        'Black/African American Pct', 'Hispanic Count', 'Hispanic Pct',
#        'Multi-Race Count', 'Multi-Race Pct', 'Pacific Islander Count',
#        'Pacific Islander Pct', 'White Count', 'White Pct',
#        'CEP Economically Disadvantaged Rate'],
#       dtype='object')

# %%
penn_phl_schools[['School Name','Student Enrollment', 'CEP Economically Disadvantaged Rate']]
# Out:
#                                           School Name  Student Enrollment  \
# 0                            John Bartram High School                 534
# 1                       West Philadelphia High School                 448
# 2         Paul Robeson High School for Human Services                 307
# 3                        William L. Sayre High School                 412
# 4                            William T. Tilden School                 360
# 5                              Motivation High School                 401
# 6                                   John Barry School                 654
# 7                            William C. Bryant School                 440
# 8                          Joseph W. Catharine School                 460
# 9                          Benjamin B. Comegys School                 485
# 10                             Sadie Alexander School                 576
# 11                             Andrew Hamilton School                 499
# ...

# %% [markdown]
# * I wanted to isolate the CEP rate to get a better understanding of the socioeconomic standing of the student bodies at each of the schools. By placing this alongside student enrollment, it provides each CEP percentage with a better reference point.

# %%
penn_phl_schools['CEP Economically Disadvantaged Rate'].value_counts()
# Out:
# 100.00    47
# 50.88      1
# 64.69      1
# 88.15      1
# 80.00      1
# 99.18      1
# 31.00      1
# 68.15      1
# 52.65      1
# 44.44      1
# 93.23      1
# 95.74      1
# 98.12      1
# 87.65      1
# 96.05      1
# 69.54      1
# 25.02      1
# 24.57      1
# 94.75      1
# .          1
# Name: CEP Economically Disadvantaged Rate, dtype: int64

# %% [markdown]
# * This code helped me to conclude that in 47 of the 65 schools, that are within three miles of Penn's campus, all of their students are eligible for CEP.  Moving forward this information is going to be important for me to keep in mind, especially when making comparisons to the rest of the schools in the district.

# %% [markdown]
# * Below is a look at the schools that have the lowest CEP rates, with William M. Meredith having the lowest at 24% of students qualifying for CEP.

# %%
penn_phl_schools.iloc[['10', '27','29','34','36','38','40','49','52']]
# Out:
#    School Year  SRC School ID  \
# 10   2018-2019            128
# 27   2018-2019            202
# 29   2018-2019            214
# 34   2018-2019            234
# 36   2018-2019            238
# 38   2018-2019            241
# 40   2018-2019            247
# 49   2018-2019            265
# 52   2018-2019            403
#
#                                           School Name Learning Network  \
# 10                             Sadie Alexander School        Network 2
# 27  High School for Creative and Performing Arts S...        Network 1
# 29                          Julia R. Masterman School        Network 1
# 34                    General George A. McCall School        Network 3
# 36                         William M. Meredith School        Network 3
# 38                      Girard Academic Music Program        Network 1
# 40                        Albert M. Greenfield School        Network 3
# 49                         Science Leadership Academy       Innovation
# ...

# %% [markdown]
# * Continuing in my exploration, I wanted to separate out all of the schools that have less than 400 total students enrolled. I wanted to take a closer look at these schools, and see if they have any other similarities amongst each other, or if any other differences arose in comparison to the schools that have upwards of 400 total students enrolled.

# %% [markdown]
#  * Below is a look at the schools that have under 400 students enrolled.

# %%
penn_phl_schools.iloc[['2', '18', '64','62', '57', '58', '59', '53', '20', '28', '37', '14','4','24','35','41','42','44','50','51']]
# Out:
#    School Year  SRC School ID                                  School Name  \
# 2    2018-2019            105  Paul Robeson High School for Human Services
# 18   2018-2019            139                          Samuel Powel School
# 64   2018-2019            856                          The Workshop School
# 62   2018-2019            509                     Parkway West High School
# 57   2018-2019            447                     Richard R. Wright School
# 58   2018-2019            453                         Edward Gideon School
# 59   2018-2019            456                     William D. Kelley School
# 53   2018-2019            414               Strawberry Mansion High School
# 20   2018-2019            142                     Martha Washington School
# 28   2018-2019            205     Science Leadership Academy Middle School
# 37   2018-2019            239                         Robert Morris School
# ...

# %% [markdown]
# * Below is a look at the three schools with the lowest enrollment of students.

# %%
penn_phl_schools.iloc[['53','63','18']]
# Out:
#    School Year  SRC School ID                      School Name  \
# 53   2018-2019            414   Strawberry Mansion High School
# 63   2018-2019            518  Vaux High School: A Big Picture
# 18   2018-2019            139              Samuel Powel School
#
#    Learning Network Grade Level  Student Enrollment  ELL Count  ELL Pct  \
# 53       Network 11  All Grades                 169          0     0.00
# 63       Innovation  All Grades                 211          3     1.42
# 18        Network 2  All Grades                 244          1     0.41
#
#     Not ELL Count  Not ELL Pct  ...  Black/African American Pct  \
# 53            169       100.00  ...                       91.12
# 63            208        98.58  ...                       93.36
# 18            243        99.59  ...                       77.05
#
#     Hispanic Count  Hispanic Pct  Multi-Race Count  Multi-Race Pct  \
# 53               6          3.55                 4            2.37
# ...

# %% [markdown]
# * Below are the three schools with the most students enrolled

# %%
penn_phl_schools.iloc[['29','47','52']]
# Out:
#    School Year  SRC School ID                             School Name  \
# 29   2018-2019            214               Julia R. Masterman School
# 47   2018-2019            262                      Academy at Palumbo
# 52   2018-2019            403  High School of Engineering and Science
#
#    Learning Network Grade Level  Student Enrollment  ELL Count  ELL Pct  \
# 29        Network 1  All Grades                1213          4     0.33
# 47        Network 1  All Grades                1060         32     3.02
# 52        Network 4  All Grades                 932         12     1.29
#
#     Not ELL Count  Not ELL Pct  ...  Black/African American Pct  \
# 29           1209        99.67  ...                       15.50
# 47           1028        96.98  ...                       43.58
# 52            920        98.71  ...                       68.24
#
#     Hispanic Count  Hispanic Pct  Multi-Race Count  Multi-Race Pct  \
# ...

# %% [markdown]
# * This file provides a "score card" for each of the schools in the Philadelphia District.  The score card is measured across 69 metrics.  I narrowed my search in on this file to only focus on the metrics that are relevant to my research questions.  But this file helps to continue to provide more insight into each of the schools.

# %%
metric_scores = pd.read_csv('../data/phl_school_metric_scores_revised.csv')

# %%
metric_scores.shape
# Out:
# (321, 337)

# %%
metric_scores.columns
# Out:
# Index(['School', 'SRC School ID', 'ULCS Code', 'Report', 'Rpt Type Long',
#        'Street Address', 'City', 'State', 'Zip Code', 'Phone Number',
#        ...
#        'FAFSA Tier', 'Student Survey College & Career Score',
#        'Student Survey College & Career Pts Earn',
#        'Student Survey College & Career Pts Poss',
#        'Student Survey College & Career Pct Earn',
#        'Student Survey College & Career Tier',
#        'Teach Effect Distinguished Score', 'Teach Effect Instruction Score',
#        'Teacher Attendance Score', 'Student Survey Teaching Score'],
#       dtype='object', length=337)

# %%
metric_scores.describe()
# Out:
#          ULCS Code      Zip Code   Enrollment  Notes  Clim Score  \
# count   321.000000    321.000000   321.000000    0.0  321.000000
# mean   4502.869159  19131.847352   593.598131    NaN   54.000000
# std    2082.983778     12.841038   334.667406    NaN   25.404724
# min    1010.000000  19102.000000    67.000000    NaN    3.000000
# 25%    3321.000000  19123.000000   398.000000    NaN   35.000000
# 50%    3424.000000  19133.000000   528.000000    NaN   56.000000
# 75%    6230.000000  19143.000000   707.000000    NaN   73.000000
# max    8770.000000  19154.000000  3363.000000    NaN   98.000000
#
#        Clim Pts Earn  Clim Pts Poss  Attendance (95%+) Score  \
# count     321.000000     321.000000               321.000000
# mean       14.739003      27.408100                47.595016
# std         7.328808       4.382329                16.960004
# min         0.700000      20.000000                 7.000000
# 25%         9.280000      20.000000                35.000000
# ...

# %%
metric_scores[['School', 'Grades Served', 'Retention Score', 'Grad Score']]
# Out:
#                                                 School Grades Served  \
# 0                             John Bartram High School        '9-12'
# 1                        West Philadelphia High School        '9-12'
# 2                            High School of the Future        '9-12'
# 3          Paul Robeson High School for Human Services        '9-12'
# 4                         William L. Sayre High School        '9-12'
# 5                             William T. Tilden School         '5-8'
# 6                               Motivation High School        '9-12'
# 7                                    John Barry School         'K-8'
# 8                             William C. Bryant School         'K-8'
# 9                           Joseph W. Catharine School         'K-5'
# 10                          Benjamin B. Comegys School         'K-8'
# 11                              Sadie Alexander School         'K-8'
# 12                              Andrew Hamilton School         'K-8'
# ...

# %%
metric_scores[['School', 'Grades Served', 'Attendance (95%+) Score', 'Attendance (<80%) Score']]
# Out:
#                                                 School Grades Served  \
# 0                             John Bartram High School        '9-12'
# 1                        West Philadelphia High School        '9-12'
# 2                            High School of the Future        '9-12'
# 3          Paul Robeson High School for Human Services        '9-12'
# 4                         William L. Sayre High School        '9-12'
# 5                             William T. Tilden School         '5-8'
# 6                               Motivation High School        '9-12'
# 7                                    John Barry School         'K-8'
# 8                             William C. Bryant School         'K-8'
# 9                           Joseph W. Catharine School         'K-5'
# 10                          Benjamin B. Comegys School         'K-8'
# 11                              Sadie Alexander School         'K-8'
# 12                              Andrew Hamilton School         'K-8'
# ...

# %% [markdown]
# * Some of the metrics I found relevant and singled out; School Name and the Grades Served, Retention Rate, Graduation Rate, percentage of students attending more than 95% of instructional days, and percentage of students attending less than 80% of instructional days.

# %% [markdown]
# * However, I found there too be too many rows with "Not Applicable" or "Data Not Available" that I decided to go back and remove from the original spreadsheet.  I then replaced it with the clean one below.
# But, note that, only the high schools' graduation rates were presented.

# %%
pd.read_csv('../data/phl_school_metric_scores_revised.csv')
# Out:
#                                                 School SRC School ID  \
# 0                             John Bartram High School           101
# 1                        West Philadelphia High School           102
# 2                            High School of the Future           103
# 3          Paul Robeson High School for Human Services           105
# 4                         William L. Sayre High School           110
# 5                             William T. Tilden School           113
# 6                               Motivation High School           119
# 7                                    John Barry School           120
# 8                             William C. Bryant School           123
# 9                           Joseph W. Catharine School           125
# 10                          Benjamin B. Comegys School           126
# 11                              Sadie Alexander School           128
# 12                              Andrew Hamilton School           129
# ...

# %%
metric_scores_rvsd = pd.read_csv('../data/phl_school_metric_scores_revised.csv')

# %%
metric_scores_rvsd[['School','Teacher Attendance Score']]
# Out:
#                                                 School  \
# 0                             John Bartram High School
# 1                        West Philadelphia High School
# 2                            High School of the Future
# 3          Paul Robeson High School for Human Services
# 4                         William L. Sayre High School
# 5                             William T. Tilden School
# 6                               Motivation High School
# 7                                    John Barry School
# 8                             William C. Bryant School
# 9                           Joseph W. Catharine School
# 10                          Benjamin B. Comegys School
# 11                              Sadie Alexander School
# 12                              Andrew Hamilton School
# 13                          Avery D. Harrington School
# 14                                 Henry C. Lea School
# 15                        William C. Longstreth School
# ...

# %% [markdown]
# * Branching off into a new segment, I wanted to separate our the "Teacher Attendance" score.  While not all of the schools had this information available, for those that did I found this information to be really relevant, especially when trying to get a holistic picture of the general culture and environment at each school.

# %% [markdown]
# * After revising the original file, I decided that I wanted to make my coding process a little simpler and separate out the schools that are within my selected radius ( no further than three miles outside of Penn's campus; 66 schools) from the remainder of schools in the district.

# %%
pd.read_csv('../data/sms_penn_schools.csv')
# Out:
#                                             School  SRC School ID  ULCS Code  \
# 0                         John Bartram High School            101       1010
# 1                    West Philadelphia High School            102       1020
# 2      Paul Robeson High School for Human Services            105       1050
# 3                     William L. Sayre High School            110       1100
# 4                         William T. Tilden School            113       1130
# 5                           Motivation High School            119       1190
# 6                                John Barry School            120       1200
# 7                         William C. Bryant School            123       1230
# 8                       Joseph W. Catharine School            125       1250
# 9                       Benjamin B. Comegys School            126       1260
# 10                          Sadie Alexander School            128       1280
# ...

# %% [markdown]
# * As a note, two schools were added into this score card spreadsheet (from the same data site but separated onto this spreadsheet) and three schools from the original Enrollment and Demographics were not featured on the list.  This all slightly edits the original list of school sites ( might not include this note ).

# %%
sms_penn_schools = pd.read_csv('../data/sms_penn_schools.csv')

# %%
sms_penn_schools.shape
# Out:
# (65, 337)

# %%
sms_penn_schools[['School', 'Grades Served', 'Retention Score', 'Grad Score']]
# Out:
#                                             School Grades Served  \
# 0                         John Bartram High School        '9-12'
# 1                    West Philadelphia High School        '9-12'
# 2      Paul Robeson High School for Human Services        '9-12'
# 3                     William L. Sayre High School        '9-12'
# 4                         William T. Tilden School         '5-8'
# 5                           Motivation High School        '9-12'
# 6                                John Barry School         'K-8'
# 7                         William C. Bryant School         'K-8'
# 8                       Joseph W. Catharine School         'K-5'
# 9                       Benjamin B. Comegys School         'K-8'
# 10                          Sadie Alexander School         'K-8'
# 11                          Andrew Hamilton School         'K-8'
# 12                      Avery D. Harrington School         'K-8'
# ...

# %% [markdown]
# * I once again singled out the metrics; "School" and "Grades Served" along with, "Retention Score" and "Graduation Score".  But this time only looking at 65 schools as opposed to over 300.

# %% [markdown]
# * As a note, to make things simpler, I will further refer to these 65 schools as "Penn" schools.

# %% [markdown]
# * Below are the top 10 schools of the "Penn" schools with the lowest retention rates.

# %%
sms_penn_schools.iloc[[56,3,26,36,59,6,12,23,22,0],[0,257]]
# Out:
#                             School  Retention Score
# 56  Strawberry Mansion High School               54
# 3     William L. Sayre High School               67
# 26   Benjamin Franklin High School               67
# 36      Delaplaine McDaniel School               68
# 59            Edward Heston School               68
# 6                John Barry School               69
# 12      Avery D. Harrington School               69
# 23      Rudolph Blankenburg School               69
# 22              Alain Locke School               70
# 0         John Bartram High School               71

# %% [markdown]
# Below are the top 10 "Penn" schools with the highest retention rates

# %%
sms_penn_schools.iloc[[55,29,39,54,27,30,52,51,49,40],[0,257]]
# Out:
#                                           School  Retention Score
# 55   High School of Engineering and Science M.S.              100
# 29                Julia R. Masterman School H.S.               99
# 39            Girard Academic Music Program H.S.               98
# 54   High School of Engineering and Science H.S.               98
# 27  High School for Creative and Performing Arts               98
# 30                 Julia R. Masterman School M.S               98
# 52                      Constitution High School               97
# 51                    Science Leadership Academy               97
# 49                            Academy at Palumbo               97
# 40            Girard Academic Music Program M.S.               96

# %% [markdown]
# Below are the top 10 "Penn" schools with the lowest graduation rates.

# %% [markdown]
# * As a note, only 18 of the schools featured a graduation rate.  Most of these schools being a high school. I still did however take this information into account.  At this point I am also flagging schools that are appearing more than once on a given list.

# %%
sms_penn_schools.iloc[[56,3,25,26,63,1,0,5,33],[0,290]]
# Out:
#                             School Grad Score
# 56  Strawberry Mansion High School         40
# 3     William L. Sayre High School         49
# 25  South Philadelphia High School         53
# 26   Benjamin Franklin High School         59
# 63        Parkway West High School         62
# 1    West Philadelphia High School         66
# 0         John Bartram High School         67
# 5           Motivation High School         83
# 33        Franklin Learning Center         85

# %% [markdown]
# * Below are the top 10 "Penn" schools with the highest graduation rates.

# %%
sms_penn_schools.iloc[[39,62,29,52,51,54,49,2,27],[0,290]]
# Out:
#                                             School Grad Score
# 39              Girard Academic Music Program H.S.        100
# 62  Parkway Center City Middle College High School        100
# 29                  Julia R. Masterman School H.S.         99
# 52                        Constitution High School         99
# 51                      Science Leadership Academy         98
# 54     High School of Engineering and Science H.S.         98
# 49                              Academy at Palumbo         96
# 2      Paul Robeson High School for Human Services         95
# 27    High School for Creative and Performing Arts         95

# %% [markdown]
# * Below are the top 10 "Penn" schools with the lowest percentage of students attending more than 95% of instructional days.

# %%
sms_penn_schools.iloc[[1,3,56,26,19,61,12,23,0],[0,243]]
# Out:
#                             School  Attendance (95%+) Score
# 1    West Philadelphia High School                       14
# 3     William L. Sayre High School                       14
# 56  Strawberry Mansion High School                       14
# 26   Benjamin Franklin High School                       17
# 19             James Rhoads School                       21
# 61  General George G. Meade School                       21
# 12      Avery D. Harrington School                       24
# 23      Rudolph Blankenburg School                       24
# 0         John Bartram High School                       26

# %% [markdown]
# * Below are the top 10 "Penn" schools with the highest percentage of students attending more than 95% of instructional days.

# %%
sms_penn_schools.iloc[[30,29,55,35,27,10,42,37,40,46], [0,243]]
# Out:
#                                           School  Attendance (95%+) Score
# 30                 Julia R. Masterman School M.S                       93
# 29                Julia R. Masterman School H.S.                       92
# 55   High School of Engineering and Science M.S.                       87
# 35               General George A. McCall School                       86
# 27  High School for Creative and Performing Arts                       82
# 10                        Sadie Alexander School                       80
# 42                   Albert M. Greenfield School                       80
# 37                    William M. Meredith School                       79
# 40            Girard Academic Music Program M.S.                       79
# 46                         Abram S. Jenks School                       77

# %% [markdown]
# * Below are the top 10 "Penn" schools with the lowest percentage of students attending less than 80% of instructional days.

# %%
sms_penn_schools.iloc[[29,30,40,10,28,35,37,42,46,47],[0,255]]
# Out:
#                                       School  Attendance (<80%) Score
# 29            Julia R. Masterman School H.S.                        0
# 30             Julia R. Masterman School M.S                        0
# 40        Girard Academic Music Program M.S.                        0
# 10                    Sadie Alexander School                        1
# 28  Science Leadership Academy Middle School                        1
# 35           General George A. McCall School                        1
# 37                William M. Meredith School                        1
# 42               Albert M. Greenfield School                        1
# 46                     Abram S. Jenks School                        1
# 47                 Eliza B. Kirkbride School                        1

# %% [markdown]
# * Below are the top 10 "Penn" schools with the highest percentage of students attending less than 80% of instructional days.

# %%
sms_penn_schools.iloc[[3,56,1,26,0,25,61,23,12,59],[0,255]]
# Out:
#                             School  Attendance (<80%) Score
# 3     William L. Sayre High School                       49
# 56  Strawberry Mansion High School                       49
# 1    West Philadelphia High School                       40
# 26   Benjamin Franklin High School                       38
# 0         John Bartram High School                       35
# 25  South Philadelphia High School                       27
# 61  General George G. Meade School                       24
# 23      Rudolph Blankenburg School                       23
# 12      Avery D. Harrington School                       21
# 59            Edward Heston School                       21

# %%
pd.read_csv('../data/sms_nonpenn_schools.csv')
# Out:
#                                                 School SRC School ID  \
# 0                             John M. Patterson School           140
# 1                                       Penrose School           144
# 2                                  Furness High School           216
# 3                                D. Newlin Fell School           219
# 4                               F. Amedee Bregy School           224
# 5                                Francis S. Key School           254
# 6                           George W. Sharswood School           263
# 7             The Science Leadership Academy at Beeber           268
# 8                               John H. Taggart School           269
# 9                                Overbrook High School           402
# 10    Murrell Dobbins Career and Technical High School           406
# 11              Lewis C. Cassidy Academics Plus School           424
# 12                               Samuel Gompers School           428
# ...

# %% [markdown]
# * This file contains the remainder of the schools in the Philadelphia district that were not classified as a "Penn" school, otherwise known as not being within the three mile radius of campus.

# %%
sms_nonpenn_schools = pd.read_csv('../data/sms_nonpenn_schools.csv')

# %%
sms_nonpenn_schools.shape
# Out:
# (254, 337)

# %%
sms_nonpenn_schools[['School','Grades Served','Retention Score', 'Grad Score']]
# Out:
#                                                 School Grades Served  \
# 0                             John M. Patterson School         'K-4'
# 1                                       Penrose School         'K-8'
# 2                                  Furness High School        '9-12'
# 3                                D. Newlin Fell School         'K-8'
# 4                               F. Amedee Bregy School         'K-8'
# 5                                Francis S. Key School         'K-6'
# 6                           George W. Sharswood School         'K-8'
# 7             The Science Leadership Academy at Beeber        '9-12'
# 8                               John H. Taggart School         'K-8'
# 9                                Overbrook High School        '9-12'
# 10    Murrell Dobbins Career and Technical High School        '9-12'
# 11              Lewis C. Cassidy Academics Plus School         'K-8'
# 12                               Samuel Gompers School         'K-8'
# ...

# %% [markdown]
# * Once again, I start my exploration by singling out the "School" and the "Grades Served" along with, "Retention Score", and "Graduation Score".  There are 254 schools in this set so it is a bit more to look over and analyze.

# %% [markdown]
# * Below, are the top 10 schools of these "Non Penn" schools that have the lowest retention rate of students.

# %%
sms_nonpenn_schools.iloc[[79,9,65,188,17,22,56,75,11,78],[0,257]]
# Out:
#                                      School  Retention Score
# 79                Theodore Roosevelt School               58
# 9                     Overbrook High School               64
# 65           Martin Luther King High School               65
# 188                  Khepera Charter School               67
# 17                  Thomas M. Peirce School               69
# 22             Thomas A. Edison High School               69
# 56                              Building 21               70
# 75                 John F. McCloskey School               71
# 11   Lewis C. Cassidy Academics Plus School               72
# 78                Samuel Pennypacker School               72

# %% [markdown]
# * Below, are the top 10 of the "Non Penn" schools that have the highest retention rate of students.

# %%
sms_nonpenn_schools.iloc[[61,172,154,173,208,211,225,88,124,167],[0,257]]
# Out:
#                                                 School  Retention Score
# 61                                 Central High School               99
# 172  Mathematics, Science, and Technology Community...               99
# 154             Eugenio Maria De Hostos Charter School               98
# 173  Mathematics, Science, and Technology Community...               98
# 208        Folk Arts-Cultural Treasures Charter School               98
# 211                   Northwood Academy Charter School               98
# 225           Franklin Towne Charter Elementary School               98
# 88           Academy for the Middle Years at Northwest               97
# 124                      Arts Academy at Benjamin Rush               97
# 167                Philadelphia Academy Charter School               94

# %% [markdown]
# * Below are the top 10 of the "Non Penn" schools that have the lowest graduation rate of students.

# %% [markdown]
# * Similarly with the last data set, not every school had an entry for their graduation rate- only 62 schools had a score.  But I once again took all of these available scores into account.

# %%
sms_nonpenn_schools.iloc[[65,9,90,22,237,60,93,239,53,27],[0,290]]
# Out:
#                                     School Grad Score
# 65          Martin Luther King High School         48
# 9                    Overbrook High School         50
# 90                   Frankford High School         55
# 22            Thomas A. Edison High School         56
# 237        Mastery Charter School at Gratz         62
# 60                  Kensington High School         63
# 93                 Samuel Fels High School         69
# 239  Universal Charter School at Audenried         69
# 53      Kensington Health Sciences Academy         71
# 27                 Penn Treaty High School         72

# %% [markdown]
# * Below are the top 10 of the "Non Penn" schools that have the highest graduation rate of students.

# %%
sms_nonpenn_schools.iloc[[89,61,124,64,172,226,7,158,26,63],[0,290]]
# Out:
#                                                 School Grad Score
# 89                                Lankenau High School        100
# 61                                 Central High School        100
# 124                      Arts Academy at Benjamin Rush         99
# 64                  Philadelphia High School for Girls         97
# 172  Mathematics, Science, and Technology Community...         97
# 226                      Tacony Academy Charter School         96
# 7             The Science Leadership Academy at Beeber         96
# 158               Multicultural Academy Charter School         95
# 26                       William W. Bodine High School         95
# 63                          Walter B. Saul High School         94

# %% [markdown]
# * Below are the top 10 of the "Non Penn" schools that have the highest percentage of students attending more than 95% of instructional days

# %%
sms_nonpenn_schools.iloc[[190,219,193,23,188,226,218,227,153,236],[0,243]]
# Out:
#                                                 School  \
# 190  Philadelphia Electrical and Technology Charter...
# 219                     Antonia Pantoja Charter School
# 193                  Mastery Charter School at Lenfest
# 23                       Philadelphia Military Academy
# 188                             Khepera Charter School
# 226                      Tacony Academy Charter School
# 218                Pan American Academy Charter School
# 227                      Tacony Academy Charter School
# 153                Christopher Columbus Charter School
# 236                   Mastery Charter School at Clymer
#
#      Attendance (95%+) Score
# 190                       17
# 219                       59
# 193                       43
# 23                        40
# 188                       83
# 226                       26
# 218                       60
# 227                       55
# 153                       77
# 236                       35

# %% [markdown]
# * As I was calculating the data for attendance, I found there to be an error in the spreadsheet I was working with.  I then went back and re-formated the file and re-uploaded it.  Because I am unsure how far back the error impacted my data, I decided to re-run all of the charts for this dataset that I already computed.

# %%
pd.read_csv('../data/updated_sms_nonpenn_schools.csv')
# Out:
#                                                 School SRC School ID  \
# 0                             John M. Patterson School           140
# 1                                  Furness High School           216
# 2                                D. Newlin Fell School           219
# 3                               F. Amedee Bregy School           224
# 4                                Francis S. Key School           254
# 5                           George W. Sharswood School           263
# 6             The Science Leadership Academy at Beeber           268
# 7                               John H. Taggart School           269
# 8                                Overbrook High School           402
# 9     Murrell Dobbins Career and Technical High School           406
# 10              Lewis C. Cassidy Academics Plus School           424
# 11                               Samuel Gompers School           428
# 12                          Robert E. Lamberton School           432
# ...

# %% [markdown]
# * This is the new updated "Non Penn Schools" file.

# %%
upd_sms_nonpenn_schools = pd.read_csv('../data/updated_sms_nonpenn_schools.csv')

# %%
upd_sms_nonpenn_schools.shape
# Out:
# (254, 337)

# %%
upd_sms_nonpenn_schools[['School', 'Grades Served', 'Retention Score', 'Grad Score']]
# Out:
#                                                 School Grades Served  \
# 0                             John M. Patterson School         'K-4'
# 1                                  Furness High School        '9-12'
# 2                                D. Newlin Fell School         'K-8'
# 3                               F. Amedee Bregy School         'K-8'
# 4                                Francis S. Key School         'K-6'
# 5                           George W. Sharswood School         'K-8'
# 6             The Science Leadership Academy at Beeber        '9-12'
# 7                               John H. Taggart School         'K-8'
# 8                                Overbrook High School        '9-12'
# 9     Murrell Dobbins Career and Technical High School        '9-12'
# 10              Lewis C. Cassidy Academics Plus School         'K-8'
# 11                               Samuel Gompers School         'K-8'
# 12                          Robert E. Lamberton School         'K-8'
# ...

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the lowest retention rates

# %%
upd_sms_nonpenn_schools.iloc[[78,8,64,188,16,21,55,74,10,77],[0,257]]
# Out:
#                                      School  Retention Score
# 78                Theodore Roosevelt School               58
# 8                     Overbrook High School               64
# 64           Martin Luther King High School               65
# 188                  Khepera Charter School               67
# 16                  Thomas M. Peirce School               69
# 21             Thomas A. Edison High School               69
# 55                              Building 21               70
# 74                 John F. McCloskey School               71
# 10   Lewis C. Cassidy Academics Plus School               72
# 77                Samuel Pennypacker School               72

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the highest retention rates

# %%
upd_sms_nonpenn_schools.iloc[[60,172,154,173,208,211,225,87,123,168],[0,257]]
# Out:
#                                                 School  Retention Score
# 60                                 Central High School               99
# 172  Mathematics, Science, and Technology Community...               99
# 154             Eugenio Maria De Hostos Charter School               98
# 173  Mathematics, Science, and Technology Community...               98
# 208        Folk Arts-Cultural Treasures Charter School               98
# 211                   Northwood Academy Charter School               98
# 225           Franklin Towne Charter Elementary School               98
# 87           Academy for the Middle Years at Northwest               97
# 123                      Arts Academy at Benjamin Rush               97
# 168                Philadelphia Academy Charter School               97

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the lowest graduation rates.
# Once again, there were only 62 schools that provided a graduation rate.

# %%
upd_sms_nonpenn_schools.iloc[[64,8,89,237,59,92,239,52,235],[0,290]]
# Out:
#                                     School Grad Score
# 64          Martin Luther King High School         48
# 8                    Overbrook High School         50
# 89                   Frankford High School         55
# 237        Mastery Charter School at Gratz         62
# 59                  Kensington High School         63
# 92                 Samuel Fels High School         69
# 239  Universal Charter School at Audenried         69
# 52      Kensington Health Sciences Academy         71
# 235         Aspira Charter School at Olney         71

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the highest graduation rate.

# %%
upd_sms_nonpenn_schools.iloc[[88,60,123,172,63,226,6,158,25,62],[0,290]]
# Out:
#                                                 School Grad Score
# 88                                Lankenau High School        100
# 60                                 Central High School        100
# 123                      Arts Academy at Benjamin Rush         99
# 172  Mathematics, Science, and Technology Community...         97
# 63                  Philadelphia High School for Girls         97
# 226                      Tacony Academy Charter School         96
# 6             The Science Leadership Academy at Beeber         96
# 158               Multicultural Academy Charter School         95
# 25                       William W. Bodine High School         95
# 62                          Walter B. Saul High School         94

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the lowest percentage of students attending more then 95% of instructional days.

# %%
upd_sms_nonpenn_schools.iloc[[235,8,64,239,190,193,21,18,20,89],[0,243]]
# Out:
#                                                 School  \
# 235                     Aspira Charter School at Olney
# 8                                Overbrook High School
# 64                      Martin Luther King High School
# 239              Universal Charter School at Audenried
# 190  Philadelphia Electrical and Technology Charter...
# 193                  Mastery Charter School at Lenfest
# 21                        Thomas A. Edison High School
# 18                            Tanner G. Duckrey School
# 20                      General George G. Meade School
# 89                               Frankford High School
#
#      Attendance (95%+) Score
# 235                        7
# 8                         16
# 64                        16
# 239                       16
# 190                       17
# 193                       43
# 21                        19
# 18                        21
# 20                        21
# 89                        21

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the highest percentage of students attending more than 95% of instructional days.

# %%
upd_sms_nonpenn_schools.iloc[[56,198,60,208,188,204,84,146,99,153],[0,243]]
# Out:
#                                           School  Attendance (95%+) Score
# 56                                  The U School                       95
# 198                   Green Woods Charter School                       88
# 60                           Central High School                       85
# 208  Folk Arts-Cultural Treasures Charter School                       83
# 188                       Khepera Charter School                       83
# 204       Philadelphia Montessori Charter School                       82
# 84                   Hill-Freedman World Academy                       69
# 146                      Joseph Greenberg School                       80
# 99                      Benjamin Franklin School                       80
# 153          Christopher Columbus Charter School                       77

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the lowest percentage of students attending less than 80% of instructional days.

# %%
upd_sms_nonpenn_schools.iloc[[29,146,172,173,205,225,6,56,60,87],[0,255]]
# Out:
#                                                 School  \
# 29                             Alexander Adaire School
# 146                            Joseph Greenberg School
# 172  Mathematics, Science, and Technology Community...
# 173  Mathematics, Science, and Technology Community...
# 205                            Ad Prima Charter School
# 225           Franklin Towne Charter Elementary School
# 6             The Science Leadership Academy at Beeber
# 56                                        The U School
# 60                                 Central High School
# 87           Academy for the Middle Years at Northwest
#
#      Attendance (<80%) Score
# 29                         0
# 146                        0
# 172                        0
# 173                        0
# 205                        0
# 225                        0
# 6                          1
# 56                         1
# 60                         1
# 87                         1

# %% [markdown]
# * Below are the top 10 "Non Penn" schools with the highest percentage of students attending less than 80% of instructional days.

# %%
upd_sms_nonpenn_schools.iloc[[8,235,64,239,59,21,89,52,92,80],[0,255]]
# Out:
#                                     School  Attendance (<80%) Score
# 8                    Overbrook High School                       48
# 235         Aspira Charter School at Olney                       44
# 64          Martin Luther King High School                       41
# 239  Universal Charter School at Audenried                       37
# 59                  Kensington High School                       37
# 21            Thomas A. Edison High School                       36
# 89                   Frankford High School                       34
# 52      Kensington Health Sciences Academy                       26
# 92                 Samuel Fels High School                       24
# 80                  Edward T. Steel School                       24
