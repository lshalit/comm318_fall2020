# %%
# %matplotlib inline
import pandas as pd

# %%
import os

# %% [markdown]
# * The more analysis I do with my data files the more that I adapt my research question based on the conclusions I am forming.

# %% [markdown]
# * At this point my research questions are:
#     - Does the proximity of Penn's campus to West Philadelphia schools have any impact on their students?
#     - What do the schools with the highest and lowest rates of graduation, enrollment, etc. have in common with each other?
#     - What are there any causal factors that drive the each schools high / low score?

# %% [markdown]
# * I uploaded all of my refined datasets and files that I have used throughout my analysis in order to work with more specific data in a fresh notebook.

# %%
pd.read_csv('../data/enrollment_demographics.csv')
# Out:
#      School Year  SRC School ID                                  School Name  \
# 0      2018-2019            101                     John Bartram High School
# 1      2018-2019            101                     John Bartram High School
# 2      2018-2019            101                     John Bartram High School
# 3      2018-2019            101                     John Bartram High School
# 4      2018-2019            101                     John Bartram High School
# 5      2018-2019            102                West Philadelphia High School
# 6      2018-2019            102                West Philadelphia High School
# 7      2018-2019            102                West Philadelphia High School
# 8      2018-2019            102                West Philadelphia High School
# 9      2018-2019            102                West Philadelphia High School
# 10     2018-2019            103                    High School of the Future
# ...

# %%
enrollment_demographics = pd.read_csv('../data/enrollment_demographics.csv')

# %%
pd.read_csv('../data/penn_phl_school_ed.csv')
# Out:
#    School Year  SRC School ID  \
# 0    2018-2019            101
# 1    2018-2019            102
# 2    2018-2019            105
# 3    2018-2019            110
# 4    2018-2019            113
# 5    2018-2019            119
# 6    2018-2019            120
# 7    2018-2019            123
# 8    2018-2019            125
# 9    2018-2019            126
# 10   2018-2019            128
# 11   2018-2019            129
# 12   2018-2019            130
# 13   2018-2019            134
# 14   2018-2019            135
# 15   2018-2019            136
# 16   2018-2019            137
# 17   2018-2019            138
# 18   2018-2019            139
# 19   2018-2019            141
# 20   2018-2019            142
# 21   2018-2019            146
# 22   2018-2019            147
# 23   2018-2019            149
# 24   2018-2019            158
# 25   2018-2019            200
# 26   2018-2019            201
# 27   2018-2019            202
# 28   2018-2019            205
# 29   2018-2019            214
# ...

# %%
penn_schools_ed = pd.read_csv('../data/penn_phl_school_ed.csv')

# %%
pd.read_csv('../data/sms_penn_schools.csv')
# Out:
#                                             School  SRC School ID  ULCS Code  \
# 0                         John Bartram High School            101       1010
# 1                    West Philadelphia High School            102       1020
# 2      Paul Robeson High School for Human Services            105       1050
# 3                     William L. Sayre High School            110       1100
# 4                         William T. Tilden School            113       1130
# 5                           Motivation High School            119       1190
# 6                                John Barry School            120       1200
# 7                         William C. Bryant School            123       1230
# 8                       Joseph W. Catharine School            125       1250
# 9                       Benjamin B. Comegys School            126       1260
# 10                          Sadie Alexander School            128       1280
# ...

# %%
sms_penn_schools = pd.read_csv('../data/sms_penn_schools.csv')

# %%
pd.read_csv('../data/updated_sms_nonpenn_schools.csv')
# Out:
#                                                 School SRC School ID  \
# 0                             John M. Patterson School           140
# 1                                  Furness High School           216
# 2                                D. Newlin Fell School           219
# 3                               F. Amedee Bregy School           224
# 4                                Francis S. Key School           254
# 5                           George W. Sharswood School           263
# 6             The Science Leadership Academy at Beeber           268
# 7                               John H. Taggart School           269
# 8                                Overbrook High School           402
# 9     Murrell Dobbins Career and Technical High School           406
# 10              Lewis C. Cassidy Academics Plus School           424
# 11                               Samuel Gompers School           428
# 12                          Robert E. Lamberton School           432
# ...

# %%
sms_nonpenn_schools = pd.read_csv('../data/updated_sms_nonpenn_schools.csv')

# %% [markdown]
# * Thus far, I have been able to conclude a couple of things from the data I have pulled and analyzed
#     - The average number of students enrolled at a  "Penn" school is 467 students while the average number of students enrolled at a "Non Penn" school is 626 students.
#     - The average graduation rate at a "Penn" school is 80% but at a "Non Penn" school the average is slightly higher at 83%.
#     - The average retention rate of students at a "Penn" school is 83% and at a "Non Penn" school this average is 86%, again slightly higher
#     - Looking at attendance, both the "Penn" and "Non Penn" schools had 47% of their students attending more than 95% of instructional days but when it came to percentage of students attending less than 80% of instructional days the average for "Penn" schools was 10% and "Non Penn" schools was 8%
#
# * There isn't much disparity between the two sectors of schools.  Meaning that the proximity of Penn's campus does not have a positive or negative impact on the general standings of each school.  Something I did notice in my analysis however was that there were multiple schools that I flagged because they appeared more than once in my "top 10" lists when looking at retention, graduation, and attendance rates.  I wanted to look to see if they have anything in common, across location and relation to Penn's campus.
#
# * As I continue researching, I continue to develop new sub-sets of research questions.

# %% [markdown]
# * I selected these metrics because they were the 5 values that I original looked at across all schools.  Doing this makes it easier to compare all of the flagged schools to each other for more than on value.

# %% [markdown]
# * Below are some of the " Penn" schools that I had previously flagged for appearing on more than one list of schools for having the lowest rates in more than one metric ( not necessarily the same metric ).

# %%
sms_penn_schools.iloc[[56,3,1,0,25,26],[0,13,257,290,243,255]]
# Out:
#                             School  Enrollment  Retention Score Grad Score  \
# 56  Strawberry Mansion High School         293               54         40
# 3     William L. Sayre High School         425               67         49
# 1    West Philadelphia High School         478               74         66
# 0         John Bartram High School         561               71         67
# 25  South Philadelphia High School         559               78         53
# 26   Benjamin Franklin High School         506               67         59
#
#     Attendance (95%+) Score  Attendance (<80%) Score
# 56                       14                       49
# 3                        14                       49
# 1                        14                       40
# 0                        26                       35
# 25                       32                       27
# 26                       17                       38

# %% [markdown]
# * Looking at the given data above, it's important to mark the similarities and the differences between all of the schools:
#     - School enrollment for example, is not similar across the schools with the highest being 561 and the lowest being 293
#     - The graduation rate also had some range; the highest percentage being 67% and the lowest being 40%.
#     - However, there is a lot of similarity across metrics between Strawberry Mansion High School and William L. Sayre High School.  I'm interested if these schools have any other similarities across additional score card values.

# %% [markdown]
# * Below are some of the "Penn" schools that I had previously flagged for appearing on more than one list of schools for having the highest rate in more than one metric.

# %%
sms_penn_schools.iloc[[29,54,49,39,46,10],[0,13,257,290,243,255]]
# Out:
#                                          School  Enrollment  Retention Score  \
# 29               Julia R. Masterman School H.S.         451               99
# 54  High School of Engineering and Science H.S.         777               98
# 49                           Academy at Palumbo         924               97
# 39           Girard Academic Music Program H.S.         253               98
# 46                        Abram S. Jenks School         300               84
# 10                       Sadie Alexander School         579               92
#
#    Grad Score  Attendance (95%+) Score  Attendance (<80%) Score
# 29         99                       92                        0
# 54         98                       77                        2
# 49         96                       74                        3
# 39        100                       63                        2
# 46          .                       77                        1
# ...

# %% [markdown]
# * Being middle schools, both the Abram S Jenks School and the Sadie Alexander School do not have graduation rates.

# %% [markdown]
# * Looking at the given data above, it's important to mark the similarities and the difference between all of the schools:
#     - School enrollment is again not similar across this spectrum schools with 924 being the highest amount of students enrolled and 253 being the lowest.
#     -  Across Retention Score, Graduation Score, and Score of Attendance (<80%) the schools are almost identical.
#     - There is a big range of school scores with Score of Attendance (95%+).
#     - The most similar schools here score wise are Julia R. Masterman High School and Sadie Alexander School.  However, they differ in the fact that one is a high school and one is a middle school.
#     - Personally I see Julia R. Masterman School as having performed the best across all metrics.

# %% [markdown]
# * Below are some of the "Non Penn" schools that I had previously flagged for appearing on more than one list of schools for having the lowest rate in more than one metric.

# %%
sms_nonpenn_schools.iloc[[8,64,89,235,59,21,78],[0,13,257,290,243,255]]
# Out:
#                              School  Enrollment  Retention Score Grad Score  \
# 8             Overbrook High School         568               64         50
# 64   Martin Luther King High School         667               65         48
# 89            Frankford High School         955               78         55
# 235  Aspira Charter School at Olney        2006               78         71
# 59           Kensington High School         579               75         63
# 21     Thomas A. Edison High School        1055               69         56
# 78        Theodore Roosevelt School         525               58          .
#
#      Attendance (95%+) Score  Attendance (<80%) Score
# 8                         16                       48
# 64                        16                       41
# 89                        21                       34
# 235                        7                       44
# 59                        25                       37
# ...

# %% [markdown]
# * Looking at the given data above, it's important to mark the similarities and the differences between all of the schools:
#     - There is no similarity across student enrollment for any of the schools.
#     - Retention rates and graduation rates, again present a range of scores; with the lowest retention rates being 58% and the highest being 78% and the lowest graduation rate being 48% and the highest being 71%.
#     - Looking at the attendance scores for both (95%+) and (<80%) there is again a range of scores
#     - There is a similarity between the Overbook High School and Martin Luther King High School and a similarity between Frankford High School and Thomas A. Edison High School that should be explored further across different metrics.
#
# * My goal is to see if there is try and determine if there is any causal reason(s) why certain schools have the low graduation and/or attendance and/or retention scores.

# %% [markdown]
# * Below are some of the "Non Penn" schools that I had previously flagged for appearing on more than one list of schools for having the highest rate in more than one metric.

# %%
sms_nonpenn_schools.iloc[[60,172,88,56,25,158,29],[0,13,257,290,243,255]]
# Out:
#                                                 School  Enrollment  \
# 60                                 Central High School        2386
# 172  Mathematics, Science, and Technology Community...         427
# 88                                Lankenau High School         348
# 56                                        The U School         291
# 25                       William W. Bodine High School         515
# 158               Multicultural Academy Charter School         279
# 29                             Alexander Adaire School         356
#
#      Retention Score Grad Score  Attendance (95%+) Score  \
# 60                99        100                       85
# 172               99         97                       63
# 88                94        100                       53
# 56                79         88                       95
# 25                95         95                       64
# 158               85         95                       50
# ...

# %% [markdown]
# * Looking at the given data above, it's important to mark the similarities and the difference between all of the schools:
#     - The enrollment for all of the schools is relatively similar except for Central High School which has 2386 students enrolled.
#     - The retention score of each of the schools is in the 90 percentile except for the U School and for Alexander Adaire School.
#     - Looking at the attendance scores there are also a few outliers. The Multicultural Academy Charter and Lankenau High School both have low scores for 95%+ attendance and high scores for <80% attendance, but have almost perfect graduation and retention rates.
#     - Personally I see Central High School as having performed the best across all of the metrics.

# %% [markdown]
# A similar theme I have seen across the "Penn" and "Non Penn" schools that have some high metric scores is that there does not seem to be a theme at all.  Not many schools have performed similarly across all of the metrics, but will instead have one high performing value.  So I am not able to conclude a causal relation between metrics.  The only causal relation that I can determine at this point is between the attendance rates.  A high "Attendance (95%+) Score" typically indicates a low "Attendance (<80%) Score" and vise versa.
