# %%
# %matplotlib inline
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Commjhub/jupyterhub/comm318_fall2019/niamhhayes/COMM318_Final_Project

# %%
print(os.listdir(os.getcwd()))
# Out:
# ['data', 'data_analysis', 'data_story_presentation', 'COMM313_Final_Project_Instructions.ipynb', '.ipynb_checkpoints', 'All_ Data_Analysis_Notebook.ipynb', 'SMS Analysis.ipynb']

# %%
pd.read_csv('data/school_metric_scores.csv')
# Out:
#                                                 School SRC School ID  \
# 0                             John Bartram High School           101
# 1                        West Philadelphia High School           102
# 2                            High School of the Future           103
# 3          Paul Robeson High School for Human Services           105
# 4                         William L. Sayre High School           110
# 5                             William T. Tilden School           113
# 6                               Motivation High School           119
# 7                                    John Barry School           120
# 8                             William C. Bryant School           123
# 9                           Joseph W. Catharine School           125
# 10                          Benjamin B. Comegys School           126
# 11                              Sadie Alexander School           128
# 12                              Andrew Hamilton School           129
# ...

# %%
metric_scores = pd.read_csv('data/school_metric_scores.csv')

# %%
metric_scores.shape
# Out:
# (321, 337)

# %%
metric_scores.count()
# Out:
# School                                      321
# SRC School ID                               321
# ULCS Code                                   321
# Report                                      321
# Rpt Type Long                               321
# Street Address                              321
# City                                        321
# State                                       321
# Zip Code                                    321
# Phone Number                                321
# Fax Number                                  314
# Governance                                  321
# Turnaround Model                             49
# Enrollment                                  321
# Website                                     321
# Grades Served                               321
# Admissions Type                             321
# Peer Group                                  321
# 2017-18 Learning Network                    321
# 2018-19 Learning Network                    321
# ...

# %%
metric_scores.describe()
# Out:
#          ULCS Code      Zip Code   Enrollment  Notes  Clim Score  \
# count   321.000000    321.000000   321.000000    0.0  321.000000
# mean   4502.869159  19131.847352   593.598131    NaN   54.000000
# std    2082.983778     12.841038   334.667406    NaN   25.404724
# min    1010.000000  19102.000000    67.000000    NaN    3.000000
# 25%    3321.000000  19123.000000   398.000000    NaN   35.000000
# 50%    3424.000000  19133.000000   528.000000    NaN   56.000000
# 75%    6230.000000  19143.000000   707.000000    NaN   73.000000
# max    8770.000000  19154.000000  3363.000000    NaN   98.000000
#
#        Clim Pts Earn  Clim Pts Poss  Attendance (95%+) Score  \
# count     321.000000     321.000000               321.000000
# mean       14.739003      27.408100                47.595016
# std         7.328808       4.382329                16.960004
# min         0.700000      20.000000                 7.000000
# 25%         9.280000      20.000000                35.000000
# ...

# %%
metric_scores.columns
# Out:
# Index(['School', 'SRC School ID', 'ULCS Code', 'Report', 'Rpt Type Long',
#        'Street Address', 'City', 'State', 'Zip Code', 'Phone Number',
#        ...
#        'FAFSA Tier', 'Student Survey College & Career Score',
#        'Student Survey College & Career Pts Earn',
#        'Student Survey College & Career Pts Poss',
#        'Student Survey College & Career Pct Earn',
#        'Student Survey College & Career Tier',
#        'Teach Effect Distinguished Score', 'Teach Effect Instruction Score',
#        'Teacher Attendance Score', 'Student Survey Teaching Score'],
#       dtype='object', length=337)

# %%
metric_scores['Grad Score']
# Out:
# 0                                 67
# 1                                 66
# 2                                 86
# 3                                 95
# 4                                 49
# 5      Not Applicable to Report Type
# 6                                 83
# 7      Not Applicable to Report Type
# 8      Not Applicable to Report Type
# 9      Not Applicable to Report Type
# 10     Not Applicable to Report Type
# 11     Not Applicable to Report Type
# 12     Not Applicable to Report Type
# 13     Not Applicable to Report Type
# 14     Not Applicable to Report Type
# 15     Not Applicable to Report Type
# 16     Not Applicable to Report Type
# 17     Not Applicable to Report Type
# 18     Not Applicable to Report Type
# 19     Not Applicable to Report Type
# 20     Not Applicable to Report Type
# 21     Not Applicable to Report Type
# 22     Not Applicable to Report Type
# 23     Not Applicable to Report Type
# 24     Not Applicable to Report Type
# ...

# %%
metric_scores['Grad Score'].value_counts()
# Out:
# Not Applicable to Report Type    238
# 89                                 6
# 87                                 4
# 95                                 4
# 88                                 4
# 100                                4
# 91                                 3
# 82                                 3
# 83                                 3
# 96                                 3
# 99                                 3
# 93                                 3
# 75                                 2
# 71                                 2
# 90                                 2
# Not Applicable                     2
# 85                                 2
# 98                                 2
# 81                                 2
# 73                                 2
# 62                                 2
# 97                                 2
# 69                                 2
# 84                                 2
# 76                                 2
# ...

# %%
metric_scores['Grad Score'].describe
# Out:
# <bound method NDFrame.describe of 0                                 67
# 1                                 66
# 2                                 86
# 3                                 95
# 4                                 49
# 5      Not Applicable to Report Type
# 6                                 83
# 7      Not Applicable to Report Type
# 8      Not Applicable to Report Type
# 9      Not Applicable to Report Type
# 10     Not Applicable to Report Type
# 11     Not Applicable to Report Type
# 12     Not Applicable to Report Type
# 13     Not Applicable to Report Type
# 14     Not Applicable to Report Type
# 15     Not Applicable to Report Type
# 16     Not Applicable to Report Type
# 17     Not Applicable to Report Type
# 18     Not Applicable to Report Type
# 19     Not Applicable to Report Type
# 20     Not Applicable to Report Type
# 21     Not Applicable to Report Type
# 22     Not Applicable to Report Type
# 23     Not Applicable to Report Type
# ...
