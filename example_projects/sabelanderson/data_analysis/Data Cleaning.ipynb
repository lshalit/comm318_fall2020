# %% [markdown]
# ### Setup

# %%
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Data

# %%
# Load in year data sets
gei_2005_df = pd.read_csv('../data/GEI_2005.csv')
gei_2010_df = pd.read_csv('../data/GEI_2010.csv')
gei_2012_df = pd.read_csv('../data/GEI_2012.csv')
gei_2015_df = pd.read_csv('../data/GEI_2015.csv')

# Truncate data frames to get rid of blank (NaN) cells
gei_2005_df = gei_2005_df.iloc[:29]
gei_2010_df = gei_2010_df.iloc[:29]
gei_2012_df = gei_2012_df.iloc[:29]
gei_2015_df = gei_2015_df.iloc[:29]

# %%
# Load in additional country information
con_info_df = pd.read_csv('../data/Country_Info.csv')

# %% [markdown]
# ### Inspect Data

# %%
gei_2005_df.head(5)
# Out:
#   Country  Gender Equality Index  WORK  Participation  \
# 0   EU-28                   62.0  70.0           77.5
# 1      BE                   66.0  71.0           72.3
# 2      BG                   56.0  67.3           77.9
# 3      CZ                   53.6  65.3           79.6
# 4      DK                   74.6  78.9           88.5
#
#    Segregation and quality of work  MONEY  Financial resources  \
# 0                             63.3   73.9                 60.9
# 1                             69.8   81.3                 73.9
# 2                             58.1   54.3                 33.5
# 3                             53.6   70.2                 50.6
# 4                             70.3   82.7                 71.2
#
#    Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 0                89.7       60.8                          67.0  ...
# 1                89.5       68.1                          70.7  ...
# ...

# %%
gei_2010_df.head(5)
# Out:
#   Country  Gender Equality Index  WORK  Participation  \
# 0   EU-28                   63.8  70.5           78.1
# 1      BE                   69.3  72.7           75.7
# 2      BG                   55.0  67.9           81.3
# 3      CZ                   55.6  64.9           78.9
# 4      DK                   75.2  79.8           88.5
#
#    Segregation and quality of work  MONEY  Financial resources  \
# 0                             63.7   78.4                 69.4
# 1                             69.8   85.5                 77.9
# 2                             56.7   60.8                 44.7
# 3                             53.3   73.8                 55.1
# 4                             71.9   83.6                 78.3
#
#    Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 0                88.6       61.8                          68.5  ...
# 1                94.0       70.6                          73.3  ...
# ...

# %%
gei_2012_df.head(5)
# Out:
#   Country  Gender Equality Index  WORK  Participation  \
# 0   EU-28                   65.0  71.0           78.7
# 1      BE                   70.2  72.8           75.4
# 2      BG                   56.9  68.7           82.0
# 3      CZ                   56.7  65.3           79.9
# 4      DK                   75.6  79.7           88.3
#
#    Segregation and quality of work  MONEY  Financial resources  \
# 0                             64.0   78.4                 70.0
# 1                             70.4   85.6                 78.6
# 2                             57.6   60.5                 44.2
# 3                             53.3   74.0                 55.8
# 4                             72.1   85.7                 80.4
#
#    Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 0                87.9       62.8                          70.4  ...
# 1                93.3       70.6                          72.5  ...
# ...

# %%
gei_2015_df.head(5)
# Out:
#   Country  Gender Equality Index  WORK  Participation  \
# 0   EU-28                   66.2  71.5           79.8
# 1      BE                   70.5  73.8           77.5
# 2      BG                   58.0  68.6           82.7
# 3      CZ                   53.6  66.1           81.8
# 4      DK                   76.8  79.2           87.2
#
#    Segregation and quality of work  MONEY  Financial resources  \
# 0                             64.0   79.6                 73.0
# 1                             70.2   87.5                 82.7
# 2                             56.9   61.9                 48.2
# 3                             53.5   75.9                 58.8
# 4                             72.0   86.6                 82.4
#
#    Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 0                86.7       63.4                          72.1  ...
# 1                92.6       71.1                          73.3  ...
# ...

# %%
gei_2005_df.shape
# Out:
# (29, 122)

# %%
gei_2005_df.columns
# Out:
# Index(['Country', 'Gender Equality Index', 'WORK', 'Participation',
#        'Segregation and quality of work', 'MONEY', 'Financial resources',
#        'Economic situation', 'KNOWLEDGE', 'Attainment and participation',
#        ...
#        'Population without unmet needs for medical examination (%) T',
#        'Population without unmet needs for dental examination (%) W',
#        'Population without unmet needs for dental examination (%) M',
#        'Population without unmet needs for dental examination (%) T',
#        'Population (number) W', 'Population (number) M',
#        'Population (number) T', 'Population (%) W', 'Population (%) M',
#        'Population (%) T'],
#       dtype='object', length=122)

# %%
gei_2005_df.describe()
# Out:
#        Gender Equality Index       WORK  Participation  \
# count              29.000000  29.000000      29.000000
# mean               58.613793  69.406897      77.327586
# std                 8.750417   4.560696       7.926623
# min                45.900000  60.800000      51.400000
# 25%                52.200000  66.300000      74.800000
# 50%                56.000000  70.000000      77.900000
# 75%                64.400000  71.700000      83.500000
# max                78.800000  78.900000      88.700000
#
#        Segregation and quality of work      MONEY  Financial resources  \
# count                        29.000000  29.000000            29.000000
# mean                         62.648276  72.500000            59.931034
# std                           5.698159  10.456167            14.609980
# min                          53.600000  53.200000            33.500000
# 25%                          58.000000  66.500000            47.300000
# ...

# %%
gei_2005_df.sample(5)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 9       ES                   62.2  68.1           70.9
# 27      SE                   78.8  78.7           88.7
# 12      IT                   49.2  60.8           63.8
# 15      LT                   55.8  71.9           84.1
# 7       IE                   61.9  71.1           75.1
#
#     Segregation and quality of work  MONEY  Financial resources  \
# 9                              65.4   73.6                 63.5
# 27                             69.9   84.1                 72.2
# 12                             58.0   76.2                 68.0
# 15                             61.5   57.0                 40.7
# 7                              67.4   79.5                 73.6
#
#     Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 9                 85.4       59.3                          68.8  ...
# 27                98.0       68.1                          70.6  ...
# ...

# %%
con_info_df.sample(5)
# Out:
#    Country Short Country Long Communist USSR Eurozone Schengen Area  \
# 26            ES        Spain        No   No      Yes           Yes
# 0             AT      Austria        No   No      Yes           Yes
# 17            LT    Lithuania       Yes  Yes      Yes           Yes
# 11            DE      Germany     Split   No      Yes           Yes
# 14            IE      Ireland        No   No      Yes            No
#
#                          Religion    Region
# 26                       Catholic  Southern
# 0                        Catholic   Central
# 17                       Catholic   Central
# 11  Split Catholic and Protestant   Central
# 14                       Catholic   Western

# %% [markdown]
# ### Merge Data Frames

# %%
# Sort data frames so the information lines up

con_info_df = con_info_df.sort_values('Country Short')

gei_2005_df = gei_2005_df.sort_values('Country')
gei_2010_df = gei_2010_df.sort_values('Country')
gei_2012_df = gei_2012_df.sort_values('Country')
gei_2015_df = gei_2015_df.sort_values('Country')

# %%
con_info_df.head(5)
# Out:
#   Country Short    Country Long Communist USSR Eurozone Schengen Area  \
# 0            AT         Austria        No   No      Yes           Yes
# 1            BE         Belgium        No   No      Yes           Yes
# 2            BG        Bulgaria       Yes   No       No            No
# 4            CY          Cyprus        No   No      Yes            No
# 5            CZ  Czech Republic       Yes   No       No           Yes
#
#    Religion        Region
# 0  Catholic       Central
# 1  Catholic       Western
# 2  Orthodox  Southeastern
# 4  Orthodox  Southeastern
# 5  Catholic       Central

# %%
# Reset the indexes 

con_info_df = con_info_df.reset_index(drop=True)

gei_2005_df = gei_2005_df.reset_index(drop=True)
gei_2010_df = gei_2010_df.reset_index(drop=True)
gei_2012_df = gei_2012_df.reset_index(drop=True)
gei_2015_df = gei_2015_df.reset_index(drop=True)

# %%
gei_2005_df.head(5)
# Out:
#   Country  Gender Equality Index  WORK  Participation  \
# 0      AT                   59.5  73.7           77.0
# 1      BE                   66.0  71.0           72.3
# 2      BG                   56.0  67.3           77.9
# 3      CY                   45.9  66.3           78.5
# 4      CZ                   53.6  65.3           79.6
#
#    Segregation and quality of work  MONEY  Financial resources  \
# 0                             70.6   82.5                 71.9
# 1                             69.8   81.3                 73.9
# 2                             58.1   54.3                 33.5
# 3                             55.9   72.6                 60.5
# 4                             53.6   70.2                 50.6
#
#    Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 0                94.6       58.9                          58.9  ...
# 1                89.5       68.1                          70.7  ...
# ...

# %%
gei_2010_df
gei_2010_df.reset_index(drop=True)

gei_2012_df
gei_2012_df.reset_index(drop=True)

gei_2015_df
gei_2015_df.reset_index(drop=True)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 0       AT                   63.3  76.1           81.4
# 1       BE                   70.5  73.8           77.5
# 2       BG                   58.0  68.6           82.7
# 3       CY                   55.1  70.7           84.7
# 4       CZ                   53.6  66.1           81.8
# 5       DE                   65.5  71.4           81.9
# 6       DK                   76.8  79.2           87.2
# 7       EE                   56.7  72.1           88.6
# 8       EL                   50.0  64.2           71.0
# 9       ES                   68.3  72.4           78.0
# 10   EU-28                   66.2  71.5           79.8
# 11      FI                   73.0  74.7           89.2
# 12      FR                   72.6  72.1           82.3
# 13      HR                   53.1  69.4           78.5
# 14      HU                   50.8  67.2           79.6
# 15      IE                   69.5  73.9           78.3
# ...

# %%
gei_2005_df.head(5)
# Out:
#   Country  Gender Equality Index  WORK  Participation  \
# 0      AT                   59.5  73.7           77.0
# 1      BE                   66.0  71.0           72.3
# 2      BG                   56.0  67.3           77.9
# 3      CY                   45.9  66.3           78.5
# 4      CZ                   53.6  65.3           79.6
#
#    Segregation and quality of work  MONEY  Financial resources  \
# 0                             70.6   82.5                 71.9
# 1                             69.8   81.3                 73.9
# 2                             58.1   54.3                 33.5
# 3                             55.9   72.6                 60.5
# 4                             53.6   70.2                 50.6
#
#    Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 0                94.6       58.9                          58.9  ...
# 1                89.5       68.1                          70.7  ...
# ...

# %%
con_info_df.head(5)
# Out:
#   Country Short    Country Long Communist USSR Eurozone Schengen Area  \
# 0            AT         Austria        No   No      Yes           Yes
# 1            BE         Belgium        No   No      Yes           Yes
# 2            BG        Bulgaria       Yes   No       No            No
# 3            CY          Cyprus        No   No      Yes            No
# 4            CZ  Czech Republic       Yes   No       No           Yes
#
#    Religion        Region
# 0  Catholic       Central
# 1  Catholic       Western
# 2  Orthodox  Southeastern
# 3  Orthodox  Southeastern
# 4  Catholic       Central

# %%
# Attach country information data to year data frames

i_2005_df = pd.concat([gei_2005_df, con_info_df], axis=1)
i_2010_df = pd.concat([gei_2010_df, con_info_df], axis=1)
i_2012_df = pd.concat([gei_2012_df, con_info_df], axis=1)
i_2015_df = pd.concat([gei_2015_df, con_info_df], axis=1)

# %%
i_2005_df.sample(5)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 22      PL                   52.4  65.2           75.1
# 11      FI                   72.0  74.2           88.2
# 18      LU                   64.4  68.1           70.2
# 19      LV                   53.4  71.7           83.6
# 8       EL                   46.8  62.5           68.0
#
#     Segregation and quality of work  MONEY  Financial resources  \
# 22                             56.7   61.4                 46.2
# 11                             62.5   80.1                 67.9
# 18                             66.1   93.1                 91.2
# 19                             61.4   56.3                 40.2
# 8                              57.5   71.9                 62.2
#
#     Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 22                81.4       56.7                          63.0  ...
# 11                94.6       56.6                          77.8  ...
# ...

# %%
# Merge year data frames

# Add year column to each data frame

i_2005_df['Year'] = '2005'

i_2010_df['Year'] = '2010'

i_2012_df['Year'] = '2012'

i_2015_df['Year'] = '2015'

# %%
i_2005_df.sample(5)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 6       DK                   74.6  78.9           88.5
# 5       DE                   60.0  68.1           75.6
# 4       CZ                   53.6  65.3           79.6
# 26      SI                   60.8  71.2           83.5
# 0       AT                   59.5  73.7           77.0
#
#     Segregation and quality of work  MONEY  Financial resources  \
# 6                              70.3   82.7                 71.2
# 5                              61.4   83.3                 73.7
# 4                              53.6   70.2                 50.6
# 26                             60.7   77.7                 62.9
# 0                              70.6   82.5                 71.9
#
#     Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 6                 96.1       73.7                          81.1  ...
# 5                 94.1       55.3                          56.7  ...
# ...

# %%
i_2010_df.sample(5)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 24      RO                   50.8  67.9           78.8
# 3       CY                   49.0  70.5           85.2
# 9       ES                   66.4  71.8           77.0
# 23      PT                   53.7  71.4           85.6
# 5       DE                   62.6  70.0           79.0
#
#     Segregation and quality of work  MONEY  Financial resources  \
# 24                             58.6   59.8                 42.5
# 3                              58.3   80.7                 74.8
# 9                              66.9   77.1                 70.4
# 23                             59.5   71.8                 60.4
# 5                              62.1   83.2                 77.1
#
#     Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 24                84.2       47.2                          50.1  ...
# 3                 87.1       55.5                          73.6  ...
# ...

# %%
i_2012_df.sample(5)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 9       ES                   67.4  72.3           77.5
# 8       EL                   50.1  63.6           69.4
# 5       DE                   64.9  70.6           80.2
# 12      FR                   68.9  71.9           81.4
# 19      LV                   56.2  74.3           86.9
#
#     Segregation and quality of work  MONEY  Financial resources  \
# 9                              67.4   76.0                 69.6
# 8                              58.4   71.1                 62.7
# 5                              62.1   84.0                 78.1
# 12                             63.5   83.7                 77.2
# 19                             63.5   59.6                 43.5
#
#     Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 9                 82.9       64.2                          73.0  ...
# 8                 80.7       54.3                          60.7  ...
# ...

# %%
i_2015_df.sample(5)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 14      HU                   50.8  67.2           79.6
# 20      MT                   60.1  71.0           68.9
# 22      PL                   56.8  66.8           79.5
# 2       BG                   58.0  68.6           82.7
# 1       BE                   70.5  73.8           77.5
#
#     Segregation and quality of work  MONEY  Financial resources  \
# 14                             56.7   70.7                 55.2
# 20                             73.1   82.4                 73.3
# 22                             56.2   73.3                 61.4
# 2                              56.9   61.9                 48.2
# 1                              70.2   87.5                 82.7
#
#     Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 14                90.5       56.9                          64.6  ...
# 20                92.8       65.2                          61.3  ...
# ...

# %%
# Merge the 4 data frames

frames = [i_2005_df, i_2010_df, i_2012_df, i_2015_df]

gei_df = pd.concat(frames)

# %%
gei_df.sample(5)
# Out:
#    Country  Gender Equality Index  WORK  Participation  \
# 4       CZ                   53.6  65.3           79.6
# 12      FR                   65.2  70.5           79.1
# 16      IT                   62.1  62.4           66.7
# 26      SI                   62.7  71.9           84.4
# 21      NL                   72.9  76.7           79.2
#
#     Segregation and quality of work  MONEY  Financial resources  \
# 4                              53.6   70.2                 50.6
# 12                             62.9   81.6                 71.4
# 16                             58.4   78.6                 73.0
# 26                             61.3   80.3                 67.3
# 21                             74.3   86.8                 79.1
#
#     Economic situation  KNOWLEDGE  Attainment and participation  ...  \
# 4                 97.4       52.2                          52.0  ...
# 12                93.2       62.3                          67.1  ...
# ...

# %%
# Save dataframe ("gei_df") to data folder as "whole_GEI_dataset"

gei_df.to_csv('../data/whole_GEI_dataset.csv', index=False)
